# %% [markdown]
# # Data Preperation
# Author: P.C.O. Maseland <br>
# Date: 03 December 2021<br>
#
# This ipynb file contains script to prepare data from accelerometer, gyroscope and magnetometer. Of all subjects (probands) the collected zipfiles, which containt csv's of activity per on-body positions, are retrieved and these csv's are converted to datasets and merged. by this we create a whole temporary dataset for accelerometer, one for gyroscope and magnetometer.
#
# The same can be done for GPS, Light and microphone. These can be found in seperate data preperation files.

# %%
#Import packages/libraries
import os
import pandas as pd
import csv
from zipfile import ZipFile
import numpy as np

# %% [markdown]
# #### Directory / file handling

# %%
#opening data files
path = 'Rawdata2/'
dirs = os.listdir(path)

# %%
#find folders
for file in dirs:
    print(file)
# Out:
# proband1
# proband10
# proband11
# proband12
# proband13
# proband14
# proband15
# proband2
# proband3
# proband4
# proband5
# proband6
# proband7
# proband8
# proband9

# %%
#create a list with all zip file paths
subpath = ''
count = 0
paths_list = []

for proband in dirs:
    subpath = path + proband
    subdir = os.listdir(subpath)
    for foldername in subdir:
        if foldername == 'data':
            subsubpath = subpath + "/data"
            subsubdir = os.listdir(subsubpath)
            for file in subsubdir:
                newpath = subsubpath + "/" + file
                paths_list.append(newpath)
                count += 1
        else:
            break

# %%
#all zip file paths
paths_list
# Out:
# ['Rawdata2/proband1/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband1/data/acc_climbingdown_sqlite.zip',
#  'Rawdata2/proband1/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband1/data/acc_climbingup_sqlite.zip',
#  'Rawdata2/proband1/data/acc_jumping_csv.zip',
#  'Rawdata2/proband1/data/acc_jumping_sqlite.zip',
#  'Rawdata2/proband1/data/acc_lying_csv.zip',
#  'Rawdata2/proband1/data/acc_lying_sqlite.zip',
#  'Rawdata2/proband1/data/acc_running_csv.zip',
#  'Rawdata2/proband1/data/acc_running_sqlite.zip',
#  'Rawdata2/proband1/data/acc_sitting_csv.zip',
#  'Rawdata2/proband1/data/acc_sitting_sqlite.zip',
#  'Rawdata2/proband1/data/acc_standing_csv.zip',
#  'Rawdata2/proband1/data/acc_standing_sqlite.zip',
#  'Rawdata2/proband1/data/acc_walking_csv.zip',
#  'Rawdata2/proband1/data/acc_walking_sqlite.zip',
#  'Rawdata2/proband1/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband1/data/gps_climbingdown_sqlite.zip',
#  'Rawdata2/proband1/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband1/data/gps_climbingup_sqlite.zip',
#  'Rawdata2/proband1/data/gps_jumping_csv.zip',
#  'Rawdata2/proband1/data/gps_jumping_sqlite.zip',
#  'Rawdata2/proband1/data/gps_lying_csv.zip',
#  'Rawdata2/proband1/data/gps_lying_sqlite.zip',
#  'Rawdata2/proband1/data/gps_running_csv.zip',
#  'Rawdata2/proband1/data/gps_running_sqlite.zip',
#  'Rawdata2/proband1/data/gps_sitting_csv.zip',
#  'Rawdata2/proband1/data/gps_sitting_sqlite.zip',
#  'Rawdata2/proband1/data/gps_standing_csv.zip',
#  'Rawdata2/proband1/data/gps_standing_sqlite.zip',
#  'Rawdata2/proband1/data/gps_walking_csv.zip',
#  'Rawdata2/proband1/data/gps_walking_sqlite.zip',
#  'Rawdata2/proband1/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband1/data/gyr_climbingdown_sqlite.zip',
#  'Rawdata2/proband1/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband1/data/gyr_climbingup_sqlite.zip',
#  'Rawdata2/proband1/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband1/data/gyr_jumping_sqlite.zip',
#  'Rawdata2/proband1/data/gyr_lying_csv.zip',
#  'Rawdata2/proband1/data/gyr_lying_sqlite.zip',
#  'Rawdata2/proband1/data/gyr_running_csv.zip',
#  'Rawdata2/proband1/data/gyr_running_sqlite.zip',
#  'Rawdata2/proband1/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband1/data/gyr_sitting_sqlite.zip',
#  'Rawdata2/proband1/data/gyr_standing_csv.zip',
#  'Rawdata2/proband1/data/gyr_standing_sqlite.zip',
#  'Rawdata2/proband1/data/gyr_walking_csv.zip',
#  'Rawdata2/proband1/data/gyr_walking_sqlite.zip',
#  'Rawdata2/proband1/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband1/data/lig_climbingdown_sqlite.zip',
#  'Rawdata2/proband1/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband1/data/lig_climbingup_sqlite.zip',
#  'Rawdata2/proband1/data/lig_jumping_csv.zip',
#  'Rawdata2/proband1/data/lig_jumping_sqlite.zip',
#  'Rawdata2/proband1/data/lig_lying_csv.zip',
#  'Rawdata2/proband1/data/lig_lying_sqlite.zip',
#  'Rawdata2/proband1/data/lig_running_csv.zip',
#  'Rawdata2/proband1/data/lig_running_sqlite.zip',
#  'Rawdata2/proband1/data/lig_sitting_csv.zip',
#  'Rawdata2/proband1/data/lig_sitting_sqlite.zip',
#  'Rawdata2/proband1/data/lig_standing_csv.zip',
#  'Rawdata2/proband1/data/lig_standing_sqlite.zip',
#  'Rawdata2/proband1/data/lig_walking_csv.zip',
#  'Rawdata2/proband1/data/lig_walking_sqlite.zip',
#  'Rawdata2/proband1/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband1/data/mag_climbingdown_sqlite.zip',
#  'Rawdata2/proband1/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband1/data/mag_climbingup_sqlite.zip',
#  'Rawdata2/proband1/data/mag_jumping_csv.zip',
#  'Rawdata2/proband1/data/mag_jumping_sqlite.zip',
#  'Rawdata2/proband1/data/mag_lying_csv.zip',
#  'Rawdata2/proband1/data/mag_lying_sqlite.zip',
#  'Rawdata2/proband1/data/mag_running_csv.zip',
#  'Rawdata2/proband1/data/mag_running_sqlite.zip',
#  'Rawdata2/proband1/data/mag_sitting_csv.zip',
#  'Rawdata2/proband1/data/mag_sitting_sqlite.zip',
#  'Rawdata2/proband1/data/mag_standing_csv.zip',
#  'Rawdata2/proband1/data/mag_standing_sqlite.zip',
#  'Rawdata2/proband1/data/mag_walking_csv.zip',
#  'Rawdata2/proband1/data/mag_walking_sqlite.zip',
#  'Rawdata2/proband1/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband1/data/mic_climbingdown_sqlite.zip',
#  'Rawdata2/proband1/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband1/data/mic_climbingup_sqlite.zip',
#  'Rawdata2/proband1/data/mic_jumping_csv.zip',
#  'Rawdata2/proband1/data/mic_jumping_sqlite.zip',
#  'Rawdata2/proband1/data/mic_lying_csv.zip',
#  'Rawdata2/proband1/data/mic_lying_sqlite.zip',
#  'Rawdata2/proband1/data/mic_running_csv.zip',
#  'Rawdata2/proband1/data/mic_running_sqlite.zip',
#  'Rawdata2/proband1/data/mic_sitting_csv.zip',
#  'Rawdata2/proband1/data/mic_sitting_sqlite.zip',
#  'Rawdata2/proband1/data/mic_standing_csv.zip',
#  'Rawdata2/proband1/data/mic_standing_sqlite.zip',
#  'Rawdata2/proband1/data/mic_walking_csv.zip',
#  'Rawdata2/proband1/data/mic_walking_sqlite.zip',
#  'Rawdata2/proband10/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband10/data/acc_climbingdown_sqlite.zip',
#  'Rawdata2/proband10/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband10/data/acc_climbingup_sqlite.zip',
#  'Rawdata2/proband10/data/acc_jumping_csv.zip',
#  'Rawdata2/proband10/data/acc_jumping_sqlite.zip',
#  'Rawdata2/proband10/data/acc_lying_csv.zip',
#  'Rawdata2/proband10/data/acc_lying_sqlite.zip',
#  'Rawdata2/proband10/data/acc_running_csv.zip',
#  'Rawdata2/proband10/data/acc_running_sqlite.zip',
#  'Rawdata2/proband10/data/acc_sitting_csv.zip',
#  'Rawdata2/proband10/data/acc_sitting_sqlite.zip',
#  'Rawdata2/proband10/data/acc_standing_csv.zip',
#  'Rawdata2/proband10/data/acc_standing_sqlite.zip',
#  'Rawdata2/proband10/data/acc_walking_csv.zip',
#  'Rawdata2/proband10/data/acc_walking_sqlite.zip',
#  'Rawdata2/proband10/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband10/data/gps_climbingdown_sqlite.zip',
#  'Rawdata2/proband10/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband10/data/gps_climbingup_sqlite.zip',
#  'Rawdata2/proband10/data/gps_jumping_csv.zip',
#  'Rawdata2/proband10/data/gps_jumping_sqlite.zip',
#  'Rawdata2/proband10/data/gps_lying_csv.zip',
#  'Rawdata2/proband10/data/gps_lying_sqlite.zip',
#  'Rawdata2/proband10/data/gps_running_csv.zip',
#  'Rawdata2/proband10/data/gps_running_sqlite.zip',
#  'Rawdata2/proband10/data/gps_sitting_csv.zip',
#  'Rawdata2/proband10/data/gps_sitting_sqlite.zip',
#  'Rawdata2/proband10/data/gps_standing_csv.zip',
#  'Rawdata2/proband10/data/gps_standing_sqlite.zip',
#  'Rawdata2/proband10/data/gps_walking_csv.zip',
#  'Rawdata2/proband10/data/gps_walking_sqlite.zip',
#  'Rawdata2/proband10/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband10/data/gyr_climbingdown_sqlite.zip',
#  'Rawdata2/proband10/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband10/data/gyr_climbingup_sqlite.zip',
#  'Rawdata2/proband10/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband10/data/gyr_jumping_sqlite.zip',
#  'Rawdata2/proband10/data/gyr_lying_csv.zip',
#  'Rawdata2/proband10/data/gyr_lying_sqlite.zip',
#  'Rawdata2/proband10/data/gyr_running_csv.zip',
#  'Rawdata2/proband10/data/gyr_running_sqlite.zip',
#  'Rawdata2/proband10/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband10/data/gyr_sitting_sqlite.zip',
#  'Rawdata2/proband10/data/gyr_standing_csv.zip',
#  'Rawdata2/proband10/data/gyr_standing_sqlite.zip',
#  'Rawdata2/proband10/data/gyr_walking_csv.zip',
#  'Rawdata2/proband10/data/gyr_walking_sqlite.zip',
#  'Rawdata2/proband10/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband10/data/lig_climbingdown_sqlite.zip',
#  'Rawdata2/proband10/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband10/data/lig_climbingup_sqlite.zip',
#  'Rawdata2/proband10/data/lig_jumping_csv.zip',
#  'Rawdata2/proband10/data/lig_jumping_sqlite.zip',
#  'Rawdata2/proband10/data/lig_lying_csv.zip',
#  'Rawdata2/proband10/data/lig_lying_sqlite.zip',
#  'Rawdata2/proband10/data/lig_running_csv.zip',
#  'Rawdata2/proband10/data/lig_running_sqlite.zip',
#  'Rawdata2/proband10/data/lig_sitting_csv.zip',
#  'Rawdata2/proband10/data/lig_sitting_sqlite.zip',
#  'Rawdata2/proband10/data/lig_standing_csv.zip',
#  'Rawdata2/proband10/data/lig_standing_sqlite.zip',
#  'Rawdata2/proband10/data/lig_walking_csv.zip',
#  'Rawdata2/proband10/data/lig_walking_sqlite.zip',
#  'Rawdata2/proband10/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband10/data/mag_climbingdown_sqlite.zip',
#  'Rawdata2/proband10/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband10/data/mag_climbingup_sqlite.zip',
#  'Rawdata2/proband10/data/mag_jumping_csv.zip',
#  'Rawdata2/proband10/data/mag_jumping_sqlite.zip',
#  'Rawdata2/proband10/data/mag_lying_csv.zip',
#  'Rawdata2/proband10/data/mag_lying_sqlite.zip',
#  'Rawdata2/proband10/data/mag_running_csv.zip',
#  'Rawdata2/proband10/data/mag_running_sqlite.zip',
#  'Rawdata2/proband10/data/mag_sitting_csv.zip',
#  'Rawdata2/proband10/data/mag_sitting_sqlite.zip',
#  'Rawdata2/proband10/data/mag_standing_csv.zip',
#  'Rawdata2/proband10/data/mag_standing_sqlite.zip',
#  'Rawdata2/proband10/data/mag_walking_csv.zip',
#  'Rawdata2/proband10/data/mag_walking_sqlite.zip',
#  'Rawdata2/proband10/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband10/data/mic_climbingdown_sqlite.zip',
#  'Rawdata2/proband10/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband10/data/mic_climbingup_sqlite.zip',
#  'Rawdata2/proband10/data/mic_jumping_csv.zip',
#  'Rawdata2/proband10/data/mic_jumping_sqlite.zip',
#  'Rawdata2/proband10/data/mic_lying_csv.zip',
#  'Rawdata2/proband10/data/mic_lying_sqlite.zip',
#  'Rawdata2/proband10/data/mic_running_csv.zip',
#  'Rawdata2/proband10/data/mic_running_sqlite.zip',
#  'Rawdata2/proband10/data/mic_sitting_csv.zip',
#  'Rawdata2/proband10/data/mic_sitting_sqlite.zip',
#  'Rawdata2/proband10/data/mic_standing_csv.zip',
#  'Rawdata2/proband10/data/mic_standing_sqlite.zip',
#  'Rawdata2/proband10/data/mic_walking_csv.zip',
#  'Rawdata2/proband10/data/mic_walking_sqlite.zip',
#  'Rawdata2/proband11/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband11/data/acc_climbingdown_sqlite.zip',
#  'Rawdata2/proband11/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband11/data/acc_climbingup_sqlite.zip',
#  'Rawdata2/proband11/data/acc_jumping_csv.zip',
#  'Rawdata2/proband11/data/acc_jumping_sqlite.zip',
#  'Rawdata2/proband11/data/acc_lying_csv.zip',
#  'Rawdata2/proband11/data/acc_lying_sqlite.zip',
#  'Rawdata2/proband11/data/acc_running_csv.zip',
#  'Rawdata2/proband11/data/acc_running_sqlite.zip',
#  'Rawdata2/proband11/data/acc_sitting_csv.zip',
#  'Rawdata2/proband11/data/acc_sitting_sqlite.zip',
#  'Rawdata2/proband11/data/acc_standing_csv.zip',
#  'Rawdata2/proband11/data/acc_standing_sqlite.zip',
#  'Rawdata2/proband11/data/acc_walking_csv.zip',
#  'Rawdata2/proband11/data/acc_walking_sqlite.zip',
#  'Rawdata2/proband11/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband11/data/gps_climbingdown_sqlite.zip',
#  'Rawdata2/proband11/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband11/data/gps_climbingup_sqlite.zip',
#  'Rawdata2/proband11/data/gps_jumping_csv.zip',
#  'Rawdata2/proband11/data/gps_jumping_sqlite.zip',
#  'Rawdata2/proband11/data/gps_lying_csv.zip',
#  'Rawdata2/proband11/data/gps_lying_sqlite.zip',
#  'Rawdata2/proband11/data/gps_running_csv.zip',
#  'Rawdata2/proband11/data/gps_running_sqlite.zip',
#  'Rawdata2/proband11/data/gps_sitting_csv.zip',
#  'Rawdata2/proband11/data/gps_sitting_sqlite.zip',
#  'Rawdata2/proband11/data/gps_standing_csv.zip',
#  'Rawdata2/proband11/data/gps_standing_sqlite.zip',
#  'Rawdata2/proband11/data/gps_walking_csv.zip',
#  'Rawdata2/proband11/data/gps_walking_sqlite.zip',
#  'Rawdata2/proband11/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband11/data/gyr_climbingdown_sqlite.zip',
#  'Rawdata2/proband11/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband11/data/gyr_climbingup_sqlite.zip',
#  'Rawdata2/proband11/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband11/data/gyr_jumping_sqlite.zip',
#  'Rawdata2/proband11/data/gyr_lying_csv.zip',
#  'Rawdata2/proband11/data/gyr_lying_sqlite.zip',
#  'Rawdata2/proband11/data/gyr_running_csv.zip',
#  'Rawdata2/proband11/data/gyr_running_sqlite.zip',
#  'Rawdata2/proband11/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband11/data/gyr_sitting_sqlite.zip',
#  'Rawdata2/proband11/data/gyr_standing_csv.zip',
#  'Rawdata2/proband11/data/gyr_standing_sqlite.zip',
#  'Rawdata2/proband11/data/gyr_walking_csv.zip',
#  'Rawdata2/proband11/data/gyr_walking_sqlite.zip',
#  'Rawdata2/proband11/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband11/data/lig_climbingdown_sqlite.zip',
#  'Rawdata2/proband11/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband11/data/lig_climbingup_sqlite.zip',
#  'Rawdata2/proband11/data/lig_jumping_csv.zip',
#  'Rawdata2/proband11/data/lig_jumping_sqlite.zip',
#  'Rawdata2/proband11/data/lig_lying_csv.zip',
#  'Rawdata2/proband11/data/lig_lying_sqlite.zip',
#  'Rawdata2/proband11/data/lig_running_csv.zip',
#  'Rawdata2/proband11/data/lig_running_sqlite.zip',
#  'Rawdata2/proband11/data/lig_sitting_csv.zip',
#  'Rawdata2/proband11/data/lig_sitting_sqlite.zip',
#  'Rawdata2/proband11/data/lig_standing_csv.zip',
#  'Rawdata2/proband11/data/lig_standing_sqlite.zip',
#  'Rawdata2/proband11/data/lig_walking_csv.zip',
#  'Rawdata2/proband11/data/lig_walking_sqlite.zip',
#  'Rawdata2/proband11/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband11/data/mag_climbingdown_sqlite.zip',
#  'Rawdata2/proband11/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband11/data/mag_climbingup_sqlite.zip',
#  'Rawdata2/proband11/data/mag_jumping_csv.zip',
#  'Rawdata2/proband11/data/mag_jumping_sqlite.zip',
#  'Rawdata2/proband11/data/mag_lying_csv.zip',
#  'Rawdata2/proband11/data/mag_lying_sqlite.zip',
#  'Rawdata2/proband11/data/mag_running_csv.zip',
#  'Rawdata2/proband11/data/mag_running_sqlite.zip',
#  'Rawdata2/proband11/data/mag_sitting_csv.zip',
#  'Rawdata2/proband11/data/mag_sitting_sqlite.zip',
#  'Rawdata2/proband11/data/mag_standing_csv.zip',
#  'Rawdata2/proband11/data/mag_standing_sqlite.zip',
#  'Rawdata2/proband11/data/mag_walking_csv.zip',
#  'Rawdata2/proband11/data/mag_walking_sqlite.zip',
#  'Rawdata2/proband11/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband11/data/mic_climbingdown_sqlite.zip',
#  'Rawdata2/proband11/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband11/data/mic_climbingup_sqlite.zip',
#  'Rawdata2/proband11/data/mic_jumping_csv.zip',
#  'Rawdata2/proband11/data/mic_jumping_sqlite.zip',
#  'Rawdata2/proband11/data/mic_lying_csv.zip',
#  'Rawdata2/proband11/data/mic_lying_sqlite.zip',
#  'Rawdata2/proband11/data/mic_running_csv.zip',
#  'Rawdata2/proband11/data/mic_running_sqlite.zip',
#  'Rawdata2/proband11/data/mic_sitting_csv.zip',
#  'Rawdata2/proband11/data/mic_sitting_sqlite.zip',
#  'Rawdata2/proband11/data/mic_standing_csv.zip',
#  'Rawdata2/proband11/data/mic_standing_sqlite.zip',
#  'Rawdata2/proband11/data/mic_walking_csv.zip',
#  'Rawdata2/proband11/data/mic_walking_sqlite.zip',
#  'Rawdata2/proband12/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband12/data/acc_climbingdown_sqlite.zip',
#  'Rawdata2/proband12/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband12/data/acc_climbingup_sqlite.zip',
#  'Rawdata2/proband12/data/acc_jumping_csv.zip',
#  'Rawdata2/proband12/data/acc_jumping_sqlite.zip',
#  'Rawdata2/proband12/data/acc_lying_csv.zip',
#  'Rawdata2/proband12/data/acc_lying_sqlite.zip',
#  'Rawdata2/proband12/data/acc_running_csv.zip',
#  'Rawdata2/proband12/data/acc_running_sqlite.zip',
#  'Rawdata2/proband12/data/acc_sitting_csv.zip',
#  'Rawdata2/proband12/data/acc_sitting_sqlite.zip',
#  'Rawdata2/proband12/data/acc_standing_csv.zip',
#  'Rawdata2/proband12/data/acc_standing_sqlite.zip',
#  'Rawdata2/proband12/data/acc_walking_csv.zip',
#  'Rawdata2/proband12/data/acc_walking_sqlite.zip',
#  'Rawdata2/proband12/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband12/data/gps_climbingdown_sqlite.zip',
#  'Rawdata2/proband12/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband12/data/gps_climbingup_sqlite.zip',
#  'Rawdata2/proband12/data/gps_jumping_csv.zip',
#  'Rawdata2/proband12/data/gps_jumping_sqlite.zip',
#  'Rawdata2/proband12/data/gps_lying_csv.zip',
#  'Rawdata2/proband12/data/gps_lying_sqlite.zip',
#  'Rawdata2/proband12/data/gps_running_csv.zip',
#  'Rawdata2/proband12/data/gps_running_sqlite.zip',
#  'Rawdata2/proband12/data/gps_sitting_csv.zip',
#  'Rawdata2/proband12/data/gps_sitting_sqlite.zip',
#  'Rawdata2/proband12/data/gps_standing_csv.zip',
#  'Rawdata2/proband12/data/gps_standing_sqlite.zip',
#  'Rawdata2/proband12/data/gps_walking_csv.zip',
#  'Rawdata2/proband12/data/gps_walking_sqlite.zip',
#  'Rawdata2/proband12/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband12/data/gyr_climbingdown_sqlite.zip',
#  'Rawdata2/proband12/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband12/data/gyr_climbingup_sqlite.zip',
#  'Rawdata2/proband12/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband12/data/gyr_jumping_sqlite.zip',
#  'Rawdata2/proband12/data/gyr_lying_csv.zip',
#  'Rawdata2/proband12/data/gyr_lying_sqlite.zip',
#  'Rawdata2/proband12/data/gyr_running_csv.zip',
#  'Rawdata2/proband12/data/gyr_running_sqlite.zip',
#  'Rawdata2/proband12/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband12/data/gyr_sitting_sqlite.zip',
#  'Rawdata2/proband12/data/gyr_standing_csv.zip',
#  'Rawdata2/proband12/data/gyr_standing_sqlite.zip',
#  'Rawdata2/proband12/data/gyr_walking_csv.zip',
#  'Rawdata2/proband12/data/gyr_walking_sqlite.zip',
#  'Rawdata2/proband12/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband12/data/lig_climbingdown_sqlite.zip',
#  'Rawdata2/proband12/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband12/data/lig_climbingup_sqlite.zip',
#  'Rawdata2/proband12/data/lig_jumping_csv.zip',
#  'Rawdata2/proband12/data/lig_jumping_sqlite.zip',
#  'Rawdata2/proband12/data/lig_lying_csv.zip',
#  'Rawdata2/proband12/data/lig_lying_sqlite.zip',
#  'Rawdata2/proband12/data/lig_running_csv.zip',
#  'Rawdata2/proband12/data/lig_running_sqlite.zip',
#  'Rawdata2/proband12/data/lig_sitting_csv.zip',
#  'Rawdata2/proband12/data/lig_sitting_sqlite.zip',
#  'Rawdata2/proband12/data/lig_standing_csv.zip',
#  'Rawdata2/proband12/data/lig_standing_sqlite.zip',
#  'Rawdata2/proband12/data/lig_walking_csv.zip',
#  'Rawdata2/proband12/data/lig_walking_sqlite.zip',
#  'Rawdata2/proband12/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband12/data/mag_climbingdown_sqlite.zip',
#  'Rawdata2/proband12/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband12/data/mag_climbingup_sqlite.zip',
#  'Rawdata2/proband12/data/mag_jumping_csv.zip',
#  'Rawdata2/proband12/data/mag_jumping_sqlite.zip',
#  'Rawdata2/proband12/data/mag_lying_csv.zip',
#  'Rawdata2/proband12/data/mag_lying_sqlite.zip',
#  'Rawdata2/proband12/data/mag_running_csv.zip',
#  'Rawdata2/proband12/data/mag_running_sqlite.zip',
#  'Rawdata2/proband12/data/mag_sitting_csv.zip',
#  'Rawdata2/proband12/data/mag_sitting_sqlite.zip',
#  'Rawdata2/proband12/data/mag_standing_csv.zip',
#  'Rawdata2/proband12/data/mag_standing_sqlite.zip',
#  'Rawdata2/proband12/data/mag_walking_csv.zip',
#  'Rawdata2/proband12/data/mag_walking_sqlite.zip',
#  'Rawdata2/proband12/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband12/data/mic_climbingdown_sqlite.zip',
#  'Rawdata2/proband12/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband12/data/mic_climbingup_sqlite.zip',
#  'Rawdata2/proband12/data/mic_jumping_csv.zip',
#  'Rawdata2/proband12/data/mic_jumping_sqlite.zip',
#  'Rawdata2/proband12/data/mic_lying_csv.zip',
#  'Rawdata2/proband12/data/mic_lying_sqlite.zip',
#  'Rawdata2/proband12/data/mic_running_csv.zip',
#  'Rawdata2/proband12/data/mic_running_sqlite.zip',
#  'Rawdata2/proband12/data/mic_sitting_csv.zip',
#  'Rawdata2/proband12/data/mic_sitting_sqlite.zip',
#  'Rawdata2/proband12/data/mic_standing_csv.zip',
#  'Rawdata2/proband12/data/mic_standing_sqlite.zip',
#  'Rawdata2/proband12/data/mic_walking_csv.zip',
#  'Rawdata2/proband12/data/mic_walking_sqlite.zip',
#  'Rawdata2/proband13/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband13/data/acc_climbingdown_sqlite.zip',
#  'Rawdata2/proband13/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband13/data/acc_climbingup_sqlite.zip',
#  'Rawdata2/proband13/data/acc_jumping_csv.zip',
#  'Rawdata2/proband13/data/acc_jumping_sqlite.zip',
#  'Rawdata2/proband13/data/acc_lying_csv.zip',
#  'Rawdata2/proband13/data/acc_lying_sqlite.zip',
#  'Rawdata2/proband13/data/acc_running_csv.zip',
#  'Rawdata2/proband13/data/acc_running_sqlite.zip',
#  'Rawdata2/proband13/data/acc_sitting_csv.zip',
#  'Rawdata2/proband13/data/acc_sitting_sqlite.zip',
#  'Rawdata2/proband13/data/acc_standing_csv.zip',
#  'Rawdata2/proband13/data/acc_standing_sqlite.zip',
#  'Rawdata2/proband13/data/acc_walking_csv.zip',
#  'Rawdata2/proband13/data/acc_walking_sqlite.zip',
#  'Rawdata2/proband13/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband13/data/gps_climbingdown_sqlite.zip',
#  'Rawdata2/proband13/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband13/data/gps_climbingup_sqlite.zip',
#  'Rawdata2/proband13/data/gps_jumping_csv.zip',
#  'Rawdata2/proband13/data/gps_jumping_sqlite.zip',
#  'Rawdata2/proband13/data/gps_lying_csv.zip',
#  'Rawdata2/proband13/data/gps_lying_sqlite.zip',
#  'Rawdata2/proband13/data/gps_running_csv.zip',
#  'Rawdata2/proband13/data/gps_running_sqlite.zip',
#  'Rawdata2/proband13/data/gps_sitting_csv.zip',
#  'Rawdata2/proband13/data/gps_sitting_sqlite.zip',
#  'Rawdata2/proband13/data/gps_standing_csv.zip',
#  'Rawdata2/proband13/data/gps_standing_sqlite.zip',
#  'Rawdata2/proband13/data/gps_walking_csv.zip',
#  'Rawdata2/proband13/data/gps_walking_sqlite.zip',
#  'Rawdata2/proband13/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband13/data/gyr_climbingdown_sqlite.zip',
#  'Rawdata2/proband13/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband13/data/gyr_climbingup_sqlite.zip',
#  'Rawdata2/proband13/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband13/data/gyr_jumping_sqlite.zip',
#  'Rawdata2/proband13/data/gyr_lying_csv.zip',
#  'Rawdata2/proband13/data/gyr_lying_sqlite.zip',
#  'Rawdata2/proband13/data/gyr_running_csv.zip',
#  'Rawdata2/proband13/data/gyr_running_sqlite.zip',
#  'Rawdata2/proband13/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband13/data/gyr_sitting_sqlite.zip',
#  'Rawdata2/proband13/data/gyr_standing_csv.zip',
#  'Rawdata2/proband13/data/gyr_standing_sqlite.zip',
#  'Rawdata2/proband13/data/gyr_walking_csv.zip',
#  'Rawdata2/proband13/data/gyr_walking_sqlite.zip',
#  'Rawdata2/proband13/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband13/data/lig_climbingdown_sqlite.zip',
#  'Rawdata2/proband13/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband13/data/lig_climbingup_sqlite.zip',
#  'Rawdata2/proband13/data/lig_jumping_csv.zip',
#  'Rawdata2/proband13/data/lig_jumping_sqlite.zip',
#  'Rawdata2/proband13/data/lig_lying_csv.zip',
#  'Rawdata2/proband13/data/lig_lying_sqlite.zip',
#  'Rawdata2/proband13/data/lig_running_csv.zip',
#  'Rawdata2/proband13/data/lig_running_sqlite.zip',
#  'Rawdata2/proband13/data/lig_sitting_csv.zip',
#  'Rawdata2/proband13/data/lig_sitting_sqlite.zip',
#  'Rawdata2/proband13/data/lig_standing_csv.zip',
#  'Rawdata2/proband13/data/lig_standing_sqlite.zip',
#  'Rawdata2/proband13/data/lig_walking_csv.zip',
#  'Rawdata2/proband13/data/lig_walking_sqlite.zip',
#  'Rawdata2/proband13/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband13/data/mag_climbingdown_sqlite.zip',
#  'Rawdata2/proband13/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband13/data/mag_climbingup_sqlite.zip',
#  'Rawdata2/proband13/data/mag_jumping_csv.zip',
#  'Rawdata2/proband13/data/mag_jumping_sqlite.zip',
#  'Rawdata2/proband13/data/mag_lying_csv.zip',
#  'Rawdata2/proband13/data/mag_lying_sqlite.zip',
#  'Rawdata2/proband13/data/mag_running_csv.zip',
#  'Rawdata2/proband13/data/mag_running_sqlite.zip',
#  'Rawdata2/proband13/data/mag_sitting_csv.zip',
#  'Rawdata2/proband13/data/mag_sitting_sqlite.zip',
#  'Rawdata2/proband13/data/mag_standing_csv.zip',
#  'Rawdata2/proband13/data/mag_standing_sqlite.zip',
#  'Rawdata2/proband13/data/mag_walking_csv.zip',
#  'Rawdata2/proband13/data/mag_walking_sqlite.zip',
#  'Rawdata2/proband13/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband13/data/mic_climbingdown_sqlite.zip',
#  'Rawdata2/proband13/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband13/data/mic_climbingup_sqlite.zip',
#  'Rawdata2/proband13/data/mic_jumping_csv.zip',
#  'Rawdata2/proband13/data/mic_jumping_sqlite.zip',
#  'Rawdata2/proband13/data/mic_lying_csv.zip',
#  'Rawdata2/proband13/data/mic_lying_sqlite.zip',
#  'Rawdata2/proband13/data/mic_running_csv.zip',
#  'Rawdata2/proband13/data/mic_running_sqlite.zip',
#  'Rawdata2/proband13/data/mic_sitting_csv.zip',
#  'Rawdata2/proband13/data/mic_sitting_sqlite.zip',
#  'Rawdata2/proband13/data/mic_standing_csv.zip',
#  'Rawdata2/proband13/data/mic_standing_sqlite.zip',
#  'Rawdata2/proband13/data/mic_walking_csv.zip',
#  'Rawdata2/proband13/data/mic_walking_sqlite.zip',
#  'Rawdata2/proband14/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband14/data/acc_climbingdown_sqlite.zip',
#  'Rawdata2/proband14/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband14/data/acc_climbingup_sqlite.zip',
#  'Rawdata2/proband14/data/acc_jumping_csv.zip',
#  'Rawdata2/proband14/data/acc_jumping_sqlite.zip',
#  'Rawdata2/proband14/data/acc_lying_csv.zip',
#  'Rawdata2/proband14/data/acc_lying_sqlite.zip',
#  'Rawdata2/proband14/data/acc_running_csv.zip',
#  'Rawdata2/proband14/data/acc_running_sqlite.zip',
#  'Rawdata2/proband14/data/acc_sitting_csv.zip',
#  'Rawdata2/proband14/data/acc_sitting_sqlite.zip',
#  'Rawdata2/proband14/data/acc_standing_csv.zip',
#  'Rawdata2/proband14/data/acc_standing_sqlite.zip',
#  'Rawdata2/proband14/data/acc_walking_csv.zip',
#  'Rawdata2/proband14/data/acc_walking_sqlite.zip',
#  'Rawdata2/proband14/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband14/data/gps_climbingdown_sqlite.zip',
#  'Rawdata2/proband14/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband14/data/gps_climbingup_sqlite.zip',
#  'Rawdata2/proband14/data/gps_jumping_csv.zip',
#  'Rawdata2/proband14/data/gps_jumping_sqlite.zip',
#  'Rawdata2/proband14/data/gps_lying_csv.zip',
#  'Rawdata2/proband14/data/gps_lying_sqlite.zip',
#  'Rawdata2/proband14/data/gps_running_csv.zip',
#  'Rawdata2/proband14/data/gps_running_sqlite.zip',
#  'Rawdata2/proband14/data/gps_sitting_csv.zip',
#  'Rawdata2/proband14/data/gps_sitting_sqlite.zip',
#  'Rawdata2/proband14/data/gps_standing_csv.zip',
#  'Rawdata2/proband14/data/gps_standing_sqlite.zip',
#  'Rawdata2/proband14/data/gps_walking_csv.zip',
#  'Rawdata2/proband14/data/gps_walking_sqlite.zip',
#  'Rawdata2/proband14/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband14/data/gyr_climbingdown_sqlite.zip',
#  'Rawdata2/proband14/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband14/data/gyr_climbingup_sqlite.zip',
#  'Rawdata2/proband14/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband14/data/gyr_jumping_sqlite.zip',
#  'Rawdata2/proband14/data/gyr_lying_csv.zip',
#  'Rawdata2/proband14/data/gyr_lying_sqlite.zip',
#  'Rawdata2/proband14/data/gyr_running_csv.zip',
#  'Rawdata2/proband14/data/gyr_running_sqlite.zip',
#  'Rawdata2/proband14/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband14/data/gyr_sitting_sqlite.zip',
#  'Rawdata2/proband14/data/gyr_standing_csv.zip',
#  'Rawdata2/proband14/data/gyr_standing_sqlite.zip',
#  'Rawdata2/proband14/data/gyr_walking_csv.zip',
#  'Rawdata2/proband14/data/gyr_walking_sqlite.zip',
#  'Rawdata2/proband14/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband14/data/lig_climbingdown_sqlite.zip',
#  'Rawdata2/proband14/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband14/data/lig_climbingup_sqlite.zip',
#  'Rawdata2/proband14/data/lig_jumping_csv.zip',
#  'Rawdata2/proband14/data/lig_jumping_sqlite.zip',
#  'Rawdata2/proband14/data/lig_lying_csv.zip',
#  'Rawdata2/proband14/data/lig_lying_sqlite.zip',
#  'Rawdata2/proband14/data/lig_running_csv.zip',
#  'Rawdata2/proband14/data/lig_running_sqlite.zip',
#  'Rawdata2/proband14/data/lig_sitting_csv.zip',
#  'Rawdata2/proband14/data/lig_sitting_sqlite.zip',
#  'Rawdata2/proband14/data/lig_standing_csv.zip',
#  'Rawdata2/proband14/data/lig_standing_sqlite.zip',
#  'Rawdata2/proband14/data/lig_walking_csv.zip',
#  'Rawdata2/proband14/data/lig_walking_sqlite.zip',
#  'Rawdata2/proband14/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband14/data/mag_climbingdown_sqlite.zip',
#  'Rawdata2/proband14/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband14/data/mag_climbingup_sqlite.zip',
#  'Rawdata2/proband14/data/mag_jumping_csv.zip',
#  'Rawdata2/proband14/data/mag_jumping_sqlite.zip',
#  'Rawdata2/proband14/data/mag_lying_csv.zip',
#  'Rawdata2/proband14/data/mag_lying_sqlite.zip',
#  'Rawdata2/proband14/data/mag_running_csv.zip',
#  'Rawdata2/proband14/data/mag_running_sqlite.zip',
#  'Rawdata2/proband14/data/mag_sitting_csv.zip',
#  'Rawdata2/proband14/data/mag_sitting_sqlite.zip',
#  'Rawdata2/proband14/data/mag_standing_csv.zip',
#  'Rawdata2/proband14/data/mag_standing_sqlite.zip',
#  'Rawdata2/proband14/data/mag_walking_csv.zip',
#  'Rawdata2/proband14/data/mag_walking_sqlite.zip',
#  'Rawdata2/proband14/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband14/data/mic_climbingdown_sqlite.zip',
#  'Rawdata2/proband14/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband14/data/mic_climbingup_sqlite.zip',
#  'Rawdata2/proband14/data/mic_jumping_csv.zip',
#  'Rawdata2/proband14/data/mic_jumping_sqlite.zip',
#  'Rawdata2/proband14/data/mic_lying_csv.zip',
#  'Rawdata2/proband14/data/mic_lying_sqlite.zip',
#  'Rawdata2/proband14/data/mic_running_csv.zip',
#  'Rawdata2/proband14/data/mic_running_sqlite.zip',
#  'Rawdata2/proband14/data/mic_sitting_csv.zip',
#  'Rawdata2/proband14/data/mic_sitting_sqlite.zip',
#  'Rawdata2/proband14/data/mic_standing_csv.zip',
#  'Rawdata2/proband14/data/mic_standing_sqlite.zip',
#  'Rawdata2/proband14/data/mic_walking_csv.zip',
#  'Rawdata2/proband14/data/mic_walking_sqlite.zip',
#  'Rawdata2/proband15/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband15/data/acc_climbingdown_sqlite.zip',
#  'Rawdata2/proband15/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband15/data/acc_climbingup_sqlite.zip',
#  'Rawdata2/proband15/data/acc_jumping_csv.zip',
#  'Rawdata2/proband15/data/acc_jumping_sqlite.zip',
#  'Rawdata2/proband15/data/acc_lying_csv.zip',
#  'Rawdata2/proband15/data/acc_lying_sqlite.zip',
#  'Rawdata2/proband15/data/acc_running_csv.zip',
#  'Rawdata2/proband15/data/acc_running_sqlite.zip',
#  'Rawdata2/proband15/data/acc_sitting_csv.zip',
#  'Rawdata2/proband15/data/acc_sitting_sqlite.zip',
#  'Rawdata2/proband15/data/acc_standing_csv.zip',
#  'Rawdata2/proband15/data/acc_standing_sqlite.zip',
#  'Rawdata2/proband15/data/acc_walking_csv.zip',
#  'Rawdata2/proband15/data/acc_walking_sqlite.zip',
#  'Rawdata2/proband15/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband15/data/gps_climbingdown_sqlite.zip',
#  'Rawdata2/proband15/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband15/data/gps_climbingup_sqlite.zip',
#  'Rawdata2/proband15/data/gps_jumping_csv.zip',
#  'Rawdata2/proband15/data/gps_jumping_sqlite.zip',
#  'Rawdata2/proband15/data/gps_lying_csv.zip',
#  'Rawdata2/proband15/data/gps_lying_sqlite.zip',
#  'Rawdata2/proband15/data/gps_running_csv.zip',
#  'Rawdata2/proband15/data/gps_running_sqlite.zip',
#  'Rawdata2/proband15/data/gps_sitting_csv.zip',
#  'Rawdata2/proband15/data/gps_sitting_sqlite.zip',
#  'Rawdata2/proband15/data/gps_standing_csv.zip',
#  'Rawdata2/proband15/data/gps_standing_sqlite.zip',
#  'Rawdata2/proband15/data/gps_walking_csv.zip',
#  'Rawdata2/proband15/data/gps_walking_sqlite.zip',
#  'Rawdata2/proband15/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband15/data/gyr_climbingdown_sqlite.zip',
#  'Rawdata2/proband15/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband15/data/gyr_climbingup_sqlite.zip',
#  'Rawdata2/proband15/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband15/data/gyr_jumping_sqlite.zip',
#  'Rawdata2/proband15/data/gyr_lying_csv.zip',
#  'Rawdata2/proband15/data/gyr_lying_sqlite.zip',
#  'Rawdata2/proband15/data/gyr_running_csv.zip',
#  'Rawdata2/proband15/data/gyr_running_sqlite.zip',
#  'Rawdata2/proband15/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband15/data/gyr_sitting_sqlite.zip',
#  'Rawdata2/proband15/data/gyr_standing_csv.zip',
#  'Rawdata2/proband15/data/gyr_standing_sqlite.zip',
#  'Rawdata2/proband15/data/gyr_walking_csv.zip',
#  'Rawdata2/proband15/data/gyr_walking_sqlite.zip',
#  'Rawdata2/proband15/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband15/data/lig_climbingdown_sqlite.zip',
#  'Rawdata2/proband15/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband15/data/lig_climbingup_sqlite.zip',
#  'Rawdata2/proband15/data/lig_jumping_csv.zip',
#  'Rawdata2/proband15/data/lig_jumping_sqlite.zip',
#  'Rawdata2/proband15/data/lig_lying_csv.zip',
#  'Rawdata2/proband15/data/lig_lying_sqlite.zip',
#  'Rawdata2/proband15/data/lig_running_csv.zip',
#  'Rawdata2/proband15/data/lig_running_sqlite.zip',
#  'Rawdata2/proband15/data/lig_sitting_csv.zip',
#  'Rawdata2/proband15/data/lig_sitting_sqlite.zip',
#  'Rawdata2/proband15/data/lig_standing_csv.zip',
#  'Rawdata2/proband15/data/lig_standing_sqlite.zip',
#  'Rawdata2/proband15/data/lig_walking_csv.zip',
#  'Rawdata2/proband15/data/lig_walking_sqlite.zip',
#  'Rawdata2/proband15/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband15/data/mag_climbingdown_sqlite.zip',
#  'Rawdata2/proband15/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband15/data/mag_climbingup_sqlite.zip',
#  'Rawdata2/proband15/data/mag_jumping_csv.zip',
#  'Rawdata2/proband15/data/mag_jumping_sqlite.zip',
#  'Rawdata2/proband15/data/mag_lying_csv.zip',
#  'Rawdata2/proband15/data/mag_lying_sqlite.zip',
#  'Rawdata2/proband15/data/mag_running_csv.zip',
#  'Rawdata2/proband15/data/mag_running_sqlite.zip',
#  'Rawdata2/proband15/data/mag_sitting_csv.zip',
#  'Rawdata2/proband15/data/mag_sitting_sqlite.zip',
#  'Rawdata2/proband15/data/mag_standing_csv.zip',
#  'Rawdata2/proband15/data/mag_standing_sqlite.zip',
#  'Rawdata2/proband15/data/mag_walking_csv.zip',
#  'Rawdata2/proband15/data/mag_walking_sqlite.zip',
#  'Rawdata2/proband15/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband15/data/mic_climbingdown_sqlite.zip',
#  'Rawdata2/proband15/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband15/data/mic_climbingup_sqlite.zip',
#  'Rawdata2/proband15/data/mic_jumping_csv.zip',
#  'Rawdata2/proband15/data/mic_jumping_sqlite.zip',
#  'Rawdata2/proband15/data/mic_lying_csv.zip',
#  'Rawdata2/proband15/data/mic_lying_sqlite.zip',
#  'Rawdata2/proband15/data/mic_running_csv.zip',
#  'Rawdata2/proband15/data/mic_running_sqlite.zip',
#  'Rawdata2/proband15/data/mic_sitting_csv.zip',
#  'Rawdata2/proband15/data/mic_sitting_sqlite.zip',
#  'Rawdata2/proband15/data/mic_standing_csv.zip',
#  'Rawdata2/proband15/data/mic_standing_sqlite.zip',
#  'Rawdata2/proband15/data/mic_walking_csv.zip',
#  'Rawdata2/proband15/data/mic_walking_sqlite.zip',
#  'Rawdata2/proband2/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband2/data/acc_climbingdown_sqlite.zip',
#  'Rawdata2/proband2/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband2/data/acc_climbingup_sqlite.zip',
#  'Rawdata2/proband2/data/acc_jumping_csv.zip',
#  'Rawdata2/proband2/data/acc_jumping_sqlite.zip',
#  'Rawdata2/proband2/data/acc_lying_csv.zip',
#  'Rawdata2/proband2/data/acc_lying_sqlite.zip',
#  'Rawdata2/proband2/data/acc_running_csv.zip',
#  'Rawdata2/proband2/data/acc_running_sqlite.zip',
#  'Rawdata2/proband2/data/acc_sitting_csv.zip',
#  'Rawdata2/proband2/data/acc_sitting_sqlite.zip',
#  'Rawdata2/proband2/data/acc_standing_csv.zip',
#  'Rawdata2/proband2/data/acc_standing_sqlite.zip',
#  'Rawdata2/proband2/data/acc_walking_csv.zip',
#  'Rawdata2/proband2/data/acc_walking_sqlite.zip',
#  'Rawdata2/proband2/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband2/data/gps_climbingdown_sqlite.zip',
#  'Rawdata2/proband2/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband2/data/gps_climbingup_sqlite.zip',
#  'Rawdata2/proband2/data/gps_jumping_csv.zip',
#  'Rawdata2/proband2/data/gps_jumping_sqlite.zip',
#  'Rawdata2/proband2/data/gps_lying_csv.zip',
#  'Rawdata2/proband2/data/gps_lying_sqlite.zip',
#  'Rawdata2/proband2/data/gps_running_csv.zip',
#  'Rawdata2/proband2/data/gps_running_sqlite.zip',
#  'Rawdata2/proband2/data/gps_sitting_csv.zip',
#  'Rawdata2/proband2/data/gps_sitting_sqlite.zip',
#  'Rawdata2/proband2/data/gps_standing_csv.zip',
#  'Rawdata2/proband2/data/gps_standing_sqlite.zip',
#  'Rawdata2/proband2/data/gps_walking_csv.zip',
#  'Rawdata2/proband2/data/gps_walking_sqlite.zip',
#  'Rawdata2/proband2/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband2/data/gyr_climbingdown_sqlite.zip',
#  'Rawdata2/proband2/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband2/data/gyr_climbingup_sqlite.zip',
#  'Rawdata2/proband2/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband2/data/gyr_jumping_sqlite.zip',
#  'Rawdata2/proband2/data/gyr_lying_csv.zip',
#  'Rawdata2/proband2/data/gyr_lying_sqlite.zip',
#  'Rawdata2/proband2/data/gyr_running_csv.zip',
#  'Rawdata2/proband2/data/gyr_running_sqlite.zip',
#  'Rawdata2/proband2/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband2/data/gyr_sitting_sqlite.zip',
#  'Rawdata2/proband2/data/gyr_standing_csv.zip',
#  'Rawdata2/proband2/data/gyr_standing_sqlite.zip',
#  'Rawdata2/proband2/data/gyr_walking_csv.zip',
#  'Rawdata2/proband2/data/gyr_walking_sqlite.zip',
#  'Rawdata2/proband2/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband2/data/lig_climbingdown_sqlite.zip',
#  'Rawdata2/proband2/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband2/data/lig_climbingup_sqlite.zip',
#  'Rawdata2/proband2/data/lig_jumping_csv.zip',
#  'Rawdata2/proband2/data/lig_jumping_sqlite.zip',
#  'Rawdata2/proband2/data/lig_lying_csv.zip',
#  'Rawdata2/proband2/data/lig_lying_sqlite.zip',
#  'Rawdata2/proband2/data/lig_running_csv.zip',
#  'Rawdata2/proband2/data/lig_running_sqlite.zip',
#  'Rawdata2/proband2/data/lig_sitting_csv.zip',
#  'Rawdata2/proband2/data/lig_sitting_sqlite.zip',
#  'Rawdata2/proband2/data/lig_standing_csv.zip',
#  'Rawdata2/proband2/data/lig_standing_sqlite.zip',
#  'Rawdata2/proband2/data/lig_walking_csv.zip',
#  'Rawdata2/proband2/data/lig_walking_sqlite.zip',
#  'Rawdata2/proband2/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband2/data/mag_climbingdown_sqlite.zip',
#  'Rawdata2/proband2/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband2/data/mag_climbingup_sqlite.zip',
#  'Rawdata2/proband2/data/mag_jumping_csv.zip',
#  'Rawdata2/proband2/data/mag_jumping_sqlite.zip',
#  'Rawdata2/proband2/data/mag_lying_csv.zip',
#  'Rawdata2/proband2/data/mag_lying_sqlite.zip',
#  'Rawdata2/proband2/data/mag_running_csv.zip',
#  'Rawdata2/proband2/data/mag_running_sqlite.zip',
#  'Rawdata2/proband2/data/mag_sitting_csv.zip',
#  'Rawdata2/proband2/data/mag_sitting_sqlite.zip',
#  'Rawdata2/proband2/data/mag_standing_csv.zip',
#  'Rawdata2/proband2/data/mag_standing_sqlite.zip',
#  'Rawdata2/proband2/data/mag_walking_csv.zip',
#  'Rawdata2/proband2/data/mag_walking_sqlite.zip',
#  'Rawdata2/proband2/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband2/data/mic_climbingdown_sqlite.zip',
#  'Rawdata2/proband2/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband2/data/mic_climbingup_sqlite.zip',
#  'Rawdata2/proband2/data/mic_jumping_csv.zip',
#  'Rawdata2/proband2/data/mic_jumping_sqlite.zip',
#  'Rawdata2/proband2/data/mic_lying_csv.zip',
#  'Rawdata2/proband2/data/mic_lying_sqlite.zip',
#  'Rawdata2/proband2/data/mic_running_csv.zip',
#  'Rawdata2/proband2/data/mic_running_sqlite.zip',
#  'Rawdata2/proband2/data/mic_sitting_csv.zip',
#  'Rawdata2/proband2/data/mic_sitting_sqlite.zip',
#  'Rawdata2/proband2/data/mic_standing_csv.zip',
#  'Rawdata2/proband2/data/mic_standing_sqlite.zip',
#  'Rawdata2/proband2/data/mic_walking_csv.zip',
#  'Rawdata2/proband2/data/mic_walking_sqlite.zip',
#  'Rawdata2/proband3/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband3/data/acc_climbingdown_sqlite.zip',
#  'Rawdata2/proband3/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband3/data/acc_climbingup_sqlite.zip',
#  'Rawdata2/proband3/data/acc_jumping_csv.zip',
#  'Rawdata2/proband3/data/acc_jumping_sqlite.zip',
#  'Rawdata2/proband3/data/acc_lying_csv.zip',
#  'Rawdata2/proband3/data/acc_lying_sqlite.zip',
#  'Rawdata2/proband3/data/acc_running_csv.zip',
#  'Rawdata2/proband3/data/acc_running_sqlite.zip',
#  'Rawdata2/proband3/data/acc_sitting_csv.zip',
#  'Rawdata2/proband3/data/acc_sitting_sqlite.zip',
#  'Rawdata2/proband3/data/acc_standing_csv.zip',
#  'Rawdata2/proband3/data/acc_standing_sqlite.zip',
#  'Rawdata2/proband3/data/acc_walking_csv.zip',
#  'Rawdata2/proband3/data/acc_walking_sqlite.zip',
#  'Rawdata2/proband3/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband3/data/gps_climbingdown_sqlite.zip',
#  'Rawdata2/proband3/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband3/data/gps_climbingup_sqlite.zip',
#  'Rawdata2/proband3/data/gps_jumping_csv.zip',
#  'Rawdata2/proband3/data/gps_jumping_sqlite.zip',
#  'Rawdata2/proband3/data/gps_lying_csv.zip',
#  'Rawdata2/proband3/data/gps_lying_sqlite.zip',
#  'Rawdata2/proband3/data/gps_running_csv.zip',
#  'Rawdata2/proband3/data/gps_running_sqlite.zip',
#  'Rawdata2/proband3/data/gps_sitting_csv.zip',
#  'Rawdata2/proband3/data/gps_sitting_sqlite.zip',
#  'Rawdata2/proband3/data/gps_standing_csv.zip',
#  'Rawdata2/proband3/data/gps_standing_sqlite.zip',
#  'Rawdata2/proband3/data/gps_walking_csv.zip',
#  'Rawdata2/proband3/data/gps_walking_sqlite.zip',
#  'Rawdata2/proband3/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband3/data/gyr_climbingdown_sqlite.zip',
#  'Rawdata2/proband3/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband3/data/gyr_climbingup_sqlite.zip',
#  'Rawdata2/proband3/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband3/data/gyr_jumping_sqlite.zip',
#  'Rawdata2/proband3/data/gyr_lying_csv.zip',
#  'Rawdata2/proband3/data/gyr_lying_sqlite.zip',
#  'Rawdata2/proband3/data/gyr_running_csv.zip',
#  'Rawdata2/proband3/data/gyr_running_sqlite.zip',
#  'Rawdata2/proband3/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband3/data/gyr_sitting_sqlite.zip',
#  'Rawdata2/proband3/data/gyr_standing_csv.zip',
#  'Rawdata2/proband3/data/gyr_standing_sqlite.zip',
#  'Rawdata2/proband3/data/gyr_walking_csv.zip',
#  'Rawdata2/proband3/data/gyr_walking_sqlite.zip',
#  'Rawdata2/proband3/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband3/data/lig_climbingdown_sqlite.zip',
#  'Rawdata2/proband3/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband3/data/lig_climbingup_sqlite.zip',
#  'Rawdata2/proband3/data/lig_jumping_csv.zip',
#  'Rawdata2/proband3/data/lig_jumping_sqlite.zip',
#  'Rawdata2/proband3/data/lig_lying_csv.zip',
#  'Rawdata2/proband3/data/lig_lying_sqlite.zip',
#  'Rawdata2/proband3/data/lig_running_csv.zip',
#  'Rawdata2/proband3/data/lig_running_sqlite.zip',
#  'Rawdata2/proband3/data/lig_sitting_csv.zip',
#  'Rawdata2/proband3/data/lig_sitting_sqlite.zip',
#  'Rawdata2/proband3/data/lig_standing_csv.zip',
#  'Rawdata2/proband3/data/lig_standing_sqlite.zip',
#  'Rawdata2/proband3/data/lig_walking_csv.zip',
#  'Rawdata2/proband3/data/lig_walking_sqlite.zip',
#  'Rawdata2/proband3/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband3/data/mag_climbingdown_sqlite.zip',
#  'Rawdata2/proband3/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband3/data/mag_climbingup_sqlite.zip',
#  'Rawdata2/proband3/data/mag_jumping_csv.zip',
#  'Rawdata2/proband3/data/mag_jumping_sqlite.zip',
#  'Rawdata2/proband3/data/mag_lying_csv.zip',
#  'Rawdata2/proband3/data/mag_lying_sqlite.zip',
#  'Rawdata2/proband3/data/mag_running_csv.zip',
#  'Rawdata2/proband3/data/mag_running_sqlite.zip',
#  'Rawdata2/proband3/data/mag_sitting_csv.zip',
#  'Rawdata2/proband3/data/mag_sitting_sqlite.zip',
#  'Rawdata2/proband3/data/mag_standing_csv.zip',
#  'Rawdata2/proband3/data/mag_standing_sqlite.zip',
#  'Rawdata2/proband3/data/mag_walking_csv.zip',
#  'Rawdata2/proband3/data/mag_walking_sqlite.zip',
#  'Rawdata2/proband3/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband3/data/mic_climbingdown_sqlite.zip',
#  'Rawdata2/proband3/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband3/data/mic_climbingup_sqlite.zip',
#  'Rawdata2/proband3/data/mic_jumping_csv.zip',
#  'Rawdata2/proband3/data/mic_jumping_sqlite.zip',
#  'Rawdata2/proband3/data/mic_lying_csv.zip',
#  'Rawdata2/proband3/data/mic_lying_sqlite.zip',
#  'Rawdata2/proband3/data/mic_running_csv.zip',
#  'Rawdata2/proband3/data/mic_running_sqlite.zip',
#  'Rawdata2/proband3/data/mic_sitting_csv.zip',
#  'Rawdata2/proband3/data/mic_sitting_sqlite.zip',
#  'Rawdata2/proband3/data/mic_standing_csv.zip',
#  'Rawdata2/proband3/data/mic_standing_sqlite.zip',
#  'Rawdata2/proband3/data/mic_walking_csv.zip',
#  'Rawdata2/proband3/data/mic_walking_sqlite.zip',
#  'Rawdata2/proband4/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband4/data/acc_climbingdown_sqlite.zip',
#  'Rawdata2/proband4/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband4/data/acc_climbingup_sqlite.zip',
#  'Rawdata2/proband4/data/acc_jumping_csv.zip',
#  'Rawdata2/proband4/data/acc_jumping_sqlite.zip',
#  'Rawdata2/proband4/data/acc_lying_csv.zip',
#  'Rawdata2/proband4/data/acc_lying_sqlite.zip',
#  'Rawdata2/proband4/data/acc_running_csv.zip',
#  'Rawdata2/proband4/data/acc_running_sqlite.zip',
#  'Rawdata2/proband4/data/acc_sitting_csv.zip',
#  'Rawdata2/proband4/data/acc_sitting_sqlite.zip',
#  'Rawdata2/proband4/data/acc_standing_csv.zip',
#  'Rawdata2/proband4/data/acc_standing_sqlite.zip',
#  'Rawdata2/proband4/data/acc_walking_csv.zip',
#  'Rawdata2/proband4/data/acc_walking_sqlite.zip',
#  'Rawdata2/proband4/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband4/data/gps_climbingdown_sqlite.zip',
#  'Rawdata2/proband4/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband4/data/gps_climbingup_sqlite.zip',
#  'Rawdata2/proband4/data/gps_jumping_csv.zip',
#  'Rawdata2/proband4/data/gps_jumping_sqlite.zip',
#  'Rawdata2/proband4/data/gps_lying_csv.zip',
#  'Rawdata2/proband4/data/gps_lying_sqlite.zip',
#  'Rawdata2/proband4/data/gps_running_csv.zip',
#  'Rawdata2/proband4/data/gps_running_sqlite.zip',
#  'Rawdata2/proband4/data/gps_sitting_csv.zip',
#  'Rawdata2/proband4/data/gps_sitting_sqlite.zip',
#  'Rawdata2/proband4/data/gps_standing_csv.zip',
#  'Rawdata2/proband4/data/gps_standing_sqlite.zip',
#  'Rawdata2/proband4/data/gps_walking_csv.zip',
#  'Rawdata2/proband4/data/gps_walking_sqlite.zip',
#  'Rawdata2/proband4/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband4/data/gyr_climbingdown_sqlite.zip',
#  'Rawdata2/proband4/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband4/data/gyr_climbingup_sqlite.zip',
#  'Rawdata2/proband4/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband4/data/gyr_jumping_sqlite.zip',
#  'Rawdata2/proband4/data/gyr_lying_csv.zip',
#  'Rawdata2/proband4/data/gyr_lying_sqlite.zip',
#  'Rawdata2/proband4/data/gyr_running_csv.zip',
#  'Rawdata2/proband4/data/gyr_running_sqlite.zip',
#  'Rawdata2/proband4/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband4/data/gyr_sitting_sqlite.zip',
#  'Rawdata2/proband4/data/gyr_standing_csv.zip',
#  'Rawdata2/proband4/data/gyr_standing_sqlite.zip',
#  'Rawdata2/proband4/data/gyr_walking_csv.zip',
#  'Rawdata2/proband4/data/gyr_walking_sqlite.zip',
#  'Rawdata2/proband4/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband4/data/lig_climbingdown_sqlite.zip',
#  'Rawdata2/proband4/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband4/data/lig_climbingup_sqlite.zip',
#  'Rawdata2/proband4/data/lig_jumping_csv.zip',
#  'Rawdata2/proband4/data/lig_jumping_sqlite.zip',
#  'Rawdata2/proband4/data/lig_lying_csv.zip',
#  'Rawdata2/proband4/data/lig_lying_sqlite.zip',
#  'Rawdata2/proband4/data/lig_running_csv.zip',
#  'Rawdata2/proband4/data/lig_running_sqlite.zip',
#  'Rawdata2/proband4/data/lig_sitting_csv.zip',
#  'Rawdata2/proband4/data/lig_sitting_sqlite.zip',
#  'Rawdata2/proband4/data/lig_standing_csv.zip',
#  'Rawdata2/proband4/data/lig_standing_sqlite.zip',
#  'Rawdata2/proband4/data/lig_walking_csv.zip',
#  'Rawdata2/proband4/data/lig_walking_sqlite.zip',
#  'Rawdata2/proband4/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband4/data/mag_climbingdown_sqlite.zip',
#  'Rawdata2/proband4/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband4/data/mag_climbingup_sqlite.zip',
#  'Rawdata2/proband4/data/mag_jumping_csv.zip',
#  'Rawdata2/proband4/data/mag_jumping_sqlite.zip',
#  'Rawdata2/proband4/data/mag_lying_csv.zip',
#  'Rawdata2/proband4/data/mag_lying_sqlite.zip',
#  'Rawdata2/proband4/data/mag_running_csv.zip',
#  'Rawdata2/proband4/data/mag_running_sqlite.zip',
#  'Rawdata2/proband4/data/mag_sitting_csv.zip',
#  'Rawdata2/proband4/data/mag_sitting_sqlite.zip',
#  'Rawdata2/proband4/data/mag_standing_csv.zip',
#  'Rawdata2/proband4/data/mag_standing_sqlite.zip',
#  'Rawdata2/proband4/data/mag_walking_csv.zip',
#  'Rawdata2/proband4/data/mag_walking_sqlite.zip',
#  'Rawdata2/proband4/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband4/data/mic_climbingdown_sqlite.zip',
#  'Rawdata2/proband4/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband4/data/mic_climbingup_sqlite.zip',
#  'Rawdata2/proband4/data/mic_jumping_csv.zip',
#  'Rawdata2/proband4/data/mic_jumping_sqlite.zip',
#  'Rawdata2/proband4/data/mic_lying_csv.zip',
#  'Rawdata2/proband4/data/mic_lying_sqlite.zip',
#  'Rawdata2/proband4/data/mic_running_csv.zip',
#  'Rawdata2/proband4/data/mic_running_sqlite.zip',
#  'Rawdata2/proband4/data/mic_sitting_csv.zip',
#  'Rawdata2/proband4/data/mic_sitting_sqlite.zip',
#  'Rawdata2/proband4/data/mic_standing_csv.zip',
#  'Rawdata2/proband4/data/mic_standing_sqlite.zip',
#  'Rawdata2/proband4/data/mic_walking_csv.zip',
#  'Rawdata2/proband4/data/mic_walking_sqlite.zip',
#  'Rawdata2/proband5/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband5/data/acc_climbingdown_sqlite.zip',
#  'Rawdata2/proband5/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband5/data/acc_climbingup_sqlite.zip',
#  'Rawdata2/proband5/data/acc_jumping_csv.zip',
#  'Rawdata2/proband5/data/acc_jumping_sqlite.zip',
#  'Rawdata2/proband5/data/acc_lying_csv.zip',
#  'Rawdata2/proband5/data/acc_lying_sqlite.zip',
#  'Rawdata2/proband5/data/acc_running_csv.zip',
#  'Rawdata2/proband5/data/acc_running_sqlite.zip',
#  'Rawdata2/proband5/data/acc_sitting_csv.zip',
#  'Rawdata2/proband5/data/acc_sitting_sqlite.zip',
#  'Rawdata2/proband5/data/acc_standing_csv.zip',
#  'Rawdata2/proband5/data/acc_standing_sqlite.zip',
#  'Rawdata2/proband5/data/acc_walking_csv.zip',
#  'Rawdata2/proband5/data/acc_walking_sqlite.zip',
#  'Rawdata2/proband5/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband5/data/gps_climbingdown_sqlite.zip',
#  'Rawdata2/proband5/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband5/data/gps_climbingup_sqlite.zip',
#  'Rawdata2/proband5/data/gps_jumping_csv.zip',
#  'Rawdata2/proband5/data/gps_jumping_sqlite.zip',
#  'Rawdata2/proband5/data/gps_lying_csv.zip',
#  'Rawdata2/proband5/data/gps_lying_sqlite.zip',
#  'Rawdata2/proband5/data/gps_running_csv.zip',
#  'Rawdata2/proband5/data/gps_running_sqlite.zip',
#  'Rawdata2/proband5/data/gps_sitting_csv.zip',
#  'Rawdata2/proband5/data/gps_sitting_sqlite.zip',
#  'Rawdata2/proband5/data/gps_standing_csv.zip',
#  'Rawdata2/proband5/data/gps_standing_sqlite.zip',
#  'Rawdata2/proband5/data/gps_walking_csv.zip',
#  'Rawdata2/proband5/data/gps_walking_sqlite.zip',
#  'Rawdata2/proband5/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband5/data/gyr_climbingdown_sqlite.zip',
#  'Rawdata2/proband5/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband5/data/gyr_climbingup_sqlite.zip',
#  'Rawdata2/proband5/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband5/data/gyr_jumping_sqlite.zip',
#  'Rawdata2/proband5/data/gyr_lying_csv.zip',
#  'Rawdata2/proband5/data/gyr_lying_sqlite.zip',
#  ...]

# %%
#remove sqlite.zip files to only use csv's
paths_list = [x for x in paths_list if "sqlite" not in x]
paths_list
# Out:
# ['Rawdata2/proband1/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband1/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband1/data/acc_jumping_csv.zip',
#  'Rawdata2/proband1/data/acc_lying_csv.zip',
#  'Rawdata2/proband1/data/acc_running_csv.zip',
#  'Rawdata2/proband1/data/acc_sitting_csv.zip',
#  'Rawdata2/proband1/data/acc_standing_csv.zip',
#  'Rawdata2/proband1/data/acc_walking_csv.zip',
#  'Rawdata2/proband1/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband1/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband1/data/gps_jumping_csv.zip',
#  'Rawdata2/proband1/data/gps_lying_csv.zip',
#  'Rawdata2/proband1/data/gps_running_csv.zip',
#  'Rawdata2/proband1/data/gps_sitting_csv.zip',
#  'Rawdata2/proband1/data/gps_standing_csv.zip',
#  'Rawdata2/proband1/data/gps_walking_csv.zip',
#  'Rawdata2/proband1/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband1/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband1/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband1/data/gyr_lying_csv.zip',
#  'Rawdata2/proband1/data/gyr_running_csv.zip',
#  'Rawdata2/proband1/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband1/data/gyr_standing_csv.zip',
#  'Rawdata2/proband1/data/gyr_walking_csv.zip',
#  'Rawdata2/proband1/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband1/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband1/data/lig_jumping_csv.zip',
#  'Rawdata2/proband1/data/lig_lying_csv.zip',
#  'Rawdata2/proband1/data/lig_running_csv.zip',
#  'Rawdata2/proband1/data/lig_sitting_csv.zip',
#  'Rawdata2/proband1/data/lig_standing_csv.zip',
#  'Rawdata2/proband1/data/lig_walking_csv.zip',
#  'Rawdata2/proband1/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband1/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband1/data/mag_jumping_csv.zip',
#  'Rawdata2/proband1/data/mag_lying_csv.zip',
#  'Rawdata2/proband1/data/mag_running_csv.zip',
#  'Rawdata2/proband1/data/mag_sitting_csv.zip',
#  'Rawdata2/proband1/data/mag_standing_csv.zip',
#  'Rawdata2/proband1/data/mag_walking_csv.zip',
#  'Rawdata2/proband1/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband1/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband1/data/mic_jumping_csv.zip',
#  'Rawdata2/proband1/data/mic_lying_csv.zip',
#  'Rawdata2/proband1/data/mic_running_csv.zip',
#  'Rawdata2/proband1/data/mic_sitting_csv.zip',
#  'Rawdata2/proband1/data/mic_standing_csv.zip',
#  'Rawdata2/proband1/data/mic_walking_csv.zip',
#  'Rawdata2/proband10/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband10/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband10/data/acc_jumping_csv.zip',
#  'Rawdata2/proband10/data/acc_lying_csv.zip',
#  'Rawdata2/proband10/data/acc_running_csv.zip',
#  'Rawdata2/proband10/data/acc_sitting_csv.zip',
#  'Rawdata2/proband10/data/acc_standing_csv.zip',
#  'Rawdata2/proband10/data/acc_walking_csv.zip',
#  'Rawdata2/proband10/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband10/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband10/data/gps_jumping_csv.zip',
#  'Rawdata2/proband10/data/gps_lying_csv.zip',
#  'Rawdata2/proband10/data/gps_running_csv.zip',
#  'Rawdata2/proband10/data/gps_sitting_csv.zip',
#  'Rawdata2/proband10/data/gps_standing_csv.zip',
#  'Rawdata2/proband10/data/gps_walking_csv.zip',
#  'Rawdata2/proband10/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband10/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband10/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband10/data/gyr_lying_csv.zip',
#  'Rawdata2/proband10/data/gyr_running_csv.zip',
#  'Rawdata2/proband10/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband10/data/gyr_standing_csv.zip',
#  'Rawdata2/proband10/data/gyr_walking_csv.zip',
#  'Rawdata2/proband10/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband10/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband10/data/lig_jumping_csv.zip',
#  'Rawdata2/proband10/data/lig_lying_csv.zip',
#  'Rawdata2/proband10/data/lig_running_csv.zip',
#  'Rawdata2/proband10/data/lig_sitting_csv.zip',
#  'Rawdata2/proband10/data/lig_standing_csv.zip',
#  'Rawdata2/proband10/data/lig_walking_csv.zip',
#  'Rawdata2/proband10/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband10/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband10/data/mag_jumping_csv.zip',
#  'Rawdata2/proband10/data/mag_lying_csv.zip',
#  'Rawdata2/proband10/data/mag_running_csv.zip',
#  'Rawdata2/proband10/data/mag_sitting_csv.zip',
#  'Rawdata2/proband10/data/mag_standing_csv.zip',
#  'Rawdata2/proband10/data/mag_walking_csv.zip',
#  'Rawdata2/proband10/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband10/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband10/data/mic_jumping_csv.zip',
#  'Rawdata2/proband10/data/mic_lying_csv.zip',
#  'Rawdata2/proband10/data/mic_running_csv.zip',
#  'Rawdata2/proband10/data/mic_sitting_csv.zip',
#  'Rawdata2/proband10/data/mic_standing_csv.zip',
#  'Rawdata2/proband10/data/mic_walking_csv.zip',
#  'Rawdata2/proband11/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband11/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband11/data/acc_jumping_csv.zip',
#  'Rawdata2/proband11/data/acc_lying_csv.zip',
#  'Rawdata2/proband11/data/acc_running_csv.zip',
#  'Rawdata2/proband11/data/acc_sitting_csv.zip',
#  'Rawdata2/proband11/data/acc_standing_csv.zip',
#  'Rawdata2/proband11/data/acc_walking_csv.zip',
#  'Rawdata2/proband11/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband11/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband11/data/gps_jumping_csv.zip',
#  'Rawdata2/proband11/data/gps_lying_csv.zip',
#  'Rawdata2/proband11/data/gps_running_csv.zip',
#  'Rawdata2/proband11/data/gps_sitting_csv.zip',
#  'Rawdata2/proband11/data/gps_standing_csv.zip',
#  'Rawdata2/proband11/data/gps_walking_csv.zip',
#  'Rawdata2/proband11/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband11/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband11/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband11/data/gyr_lying_csv.zip',
#  'Rawdata2/proband11/data/gyr_running_csv.zip',
#  'Rawdata2/proband11/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband11/data/gyr_standing_csv.zip',
#  'Rawdata2/proband11/data/gyr_walking_csv.zip',
#  'Rawdata2/proband11/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband11/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband11/data/lig_jumping_csv.zip',
#  'Rawdata2/proband11/data/lig_lying_csv.zip',
#  'Rawdata2/proband11/data/lig_running_csv.zip',
#  'Rawdata2/proband11/data/lig_sitting_csv.zip',
#  'Rawdata2/proband11/data/lig_standing_csv.zip',
#  'Rawdata2/proband11/data/lig_walking_csv.zip',
#  'Rawdata2/proband11/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband11/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband11/data/mag_jumping_csv.zip',
#  'Rawdata2/proband11/data/mag_lying_csv.zip',
#  'Rawdata2/proband11/data/mag_running_csv.zip',
#  'Rawdata2/proband11/data/mag_sitting_csv.zip',
#  'Rawdata2/proband11/data/mag_standing_csv.zip',
#  'Rawdata2/proband11/data/mag_walking_csv.zip',
#  'Rawdata2/proband11/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband11/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband11/data/mic_jumping_csv.zip',
#  'Rawdata2/proband11/data/mic_lying_csv.zip',
#  'Rawdata2/proband11/data/mic_running_csv.zip',
#  'Rawdata2/proband11/data/mic_sitting_csv.zip',
#  'Rawdata2/proband11/data/mic_standing_csv.zip',
#  'Rawdata2/proband11/data/mic_walking_csv.zip',
#  'Rawdata2/proband12/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband12/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband12/data/acc_jumping_csv.zip',
#  'Rawdata2/proband12/data/acc_lying_csv.zip',
#  'Rawdata2/proband12/data/acc_running_csv.zip',
#  'Rawdata2/proband12/data/acc_sitting_csv.zip',
#  'Rawdata2/proband12/data/acc_standing_csv.zip',
#  'Rawdata2/proband12/data/acc_walking_csv.zip',
#  'Rawdata2/proband12/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband12/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband12/data/gps_jumping_csv.zip',
#  'Rawdata2/proband12/data/gps_lying_csv.zip',
#  'Rawdata2/proband12/data/gps_running_csv.zip',
#  'Rawdata2/proband12/data/gps_sitting_csv.zip',
#  'Rawdata2/proband12/data/gps_standing_csv.zip',
#  'Rawdata2/proband12/data/gps_walking_csv.zip',
#  'Rawdata2/proband12/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband12/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband12/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband12/data/gyr_lying_csv.zip',
#  'Rawdata2/proband12/data/gyr_running_csv.zip',
#  'Rawdata2/proband12/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband12/data/gyr_standing_csv.zip',
#  'Rawdata2/proband12/data/gyr_walking_csv.zip',
#  'Rawdata2/proband12/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband12/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband12/data/lig_jumping_csv.zip',
#  'Rawdata2/proband12/data/lig_lying_csv.zip',
#  'Rawdata2/proband12/data/lig_running_csv.zip',
#  'Rawdata2/proband12/data/lig_sitting_csv.zip',
#  'Rawdata2/proband12/data/lig_standing_csv.zip',
#  'Rawdata2/proband12/data/lig_walking_csv.zip',
#  'Rawdata2/proband12/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband12/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband12/data/mag_jumping_csv.zip',
#  'Rawdata2/proband12/data/mag_lying_csv.zip',
#  'Rawdata2/proband12/data/mag_running_csv.zip',
#  'Rawdata2/proband12/data/mag_sitting_csv.zip',
#  'Rawdata2/proband12/data/mag_standing_csv.zip',
#  'Rawdata2/proband12/data/mag_walking_csv.zip',
#  'Rawdata2/proband12/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband12/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband12/data/mic_jumping_csv.zip',
#  'Rawdata2/proband12/data/mic_lying_csv.zip',
#  'Rawdata2/proband12/data/mic_running_csv.zip',
#  'Rawdata2/proband12/data/mic_sitting_csv.zip',
#  'Rawdata2/proband12/data/mic_standing_csv.zip',
#  'Rawdata2/proband12/data/mic_walking_csv.zip',
#  'Rawdata2/proband13/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband13/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband13/data/acc_jumping_csv.zip',
#  'Rawdata2/proband13/data/acc_lying_csv.zip',
#  'Rawdata2/proband13/data/acc_running_csv.zip',
#  'Rawdata2/proband13/data/acc_sitting_csv.zip',
#  'Rawdata2/proband13/data/acc_standing_csv.zip',
#  'Rawdata2/proband13/data/acc_walking_csv.zip',
#  'Rawdata2/proband13/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband13/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband13/data/gps_jumping_csv.zip',
#  'Rawdata2/proband13/data/gps_lying_csv.zip',
#  'Rawdata2/proband13/data/gps_running_csv.zip',
#  'Rawdata2/proband13/data/gps_sitting_csv.zip',
#  'Rawdata2/proband13/data/gps_standing_csv.zip',
#  'Rawdata2/proband13/data/gps_walking_csv.zip',
#  'Rawdata2/proband13/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband13/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband13/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband13/data/gyr_lying_csv.zip',
#  'Rawdata2/proband13/data/gyr_running_csv.zip',
#  'Rawdata2/proband13/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband13/data/gyr_standing_csv.zip',
#  'Rawdata2/proband13/data/gyr_walking_csv.zip',
#  'Rawdata2/proband13/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband13/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband13/data/lig_jumping_csv.zip',
#  'Rawdata2/proband13/data/lig_lying_csv.zip',
#  'Rawdata2/proband13/data/lig_running_csv.zip',
#  'Rawdata2/proband13/data/lig_sitting_csv.zip',
#  'Rawdata2/proband13/data/lig_standing_csv.zip',
#  'Rawdata2/proband13/data/lig_walking_csv.zip',
#  'Rawdata2/proband13/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband13/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband13/data/mag_jumping_csv.zip',
#  'Rawdata2/proband13/data/mag_lying_csv.zip',
#  'Rawdata2/proband13/data/mag_running_csv.zip',
#  'Rawdata2/proband13/data/mag_sitting_csv.zip',
#  'Rawdata2/proband13/data/mag_standing_csv.zip',
#  'Rawdata2/proband13/data/mag_walking_csv.zip',
#  'Rawdata2/proband13/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband13/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband13/data/mic_jumping_csv.zip',
#  'Rawdata2/proband13/data/mic_lying_csv.zip',
#  'Rawdata2/proband13/data/mic_running_csv.zip',
#  'Rawdata2/proband13/data/mic_sitting_csv.zip',
#  'Rawdata2/proband13/data/mic_standing_csv.zip',
#  'Rawdata2/proband13/data/mic_walking_csv.zip',
#  'Rawdata2/proband14/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband14/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband14/data/acc_jumping_csv.zip',
#  'Rawdata2/proband14/data/acc_lying_csv.zip',
#  'Rawdata2/proband14/data/acc_running_csv.zip',
#  'Rawdata2/proband14/data/acc_sitting_csv.zip',
#  'Rawdata2/proband14/data/acc_standing_csv.zip',
#  'Rawdata2/proband14/data/acc_walking_csv.zip',
#  'Rawdata2/proband14/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband14/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband14/data/gps_jumping_csv.zip',
#  'Rawdata2/proband14/data/gps_lying_csv.zip',
#  'Rawdata2/proband14/data/gps_running_csv.zip',
#  'Rawdata2/proband14/data/gps_sitting_csv.zip',
#  'Rawdata2/proband14/data/gps_standing_csv.zip',
#  'Rawdata2/proband14/data/gps_walking_csv.zip',
#  'Rawdata2/proband14/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband14/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband14/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband14/data/gyr_lying_csv.zip',
#  'Rawdata2/proband14/data/gyr_running_csv.zip',
#  'Rawdata2/proband14/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband14/data/gyr_standing_csv.zip',
#  'Rawdata2/proband14/data/gyr_walking_csv.zip',
#  'Rawdata2/proband14/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband14/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband14/data/lig_jumping_csv.zip',
#  'Rawdata2/proband14/data/lig_lying_csv.zip',
#  'Rawdata2/proband14/data/lig_running_csv.zip',
#  'Rawdata2/proband14/data/lig_sitting_csv.zip',
#  'Rawdata2/proband14/data/lig_standing_csv.zip',
#  'Rawdata2/proband14/data/lig_walking_csv.zip',
#  'Rawdata2/proband14/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband14/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband14/data/mag_jumping_csv.zip',
#  'Rawdata2/proband14/data/mag_lying_csv.zip',
#  'Rawdata2/proband14/data/mag_running_csv.zip',
#  'Rawdata2/proband14/data/mag_sitting_csv.zip',
#  'Rawdata2/proband14/data/mag_standing_csv.zip',
#  'Rawdata2/proband14/data/mag_walking_csv.zip',
#  'Rawdata2/proband14/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband14/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband14/data/mic_jumping_csv.zip',
#  'Rawdata2/proband14/data/mic_lying_csv.zip',
#  'Rawdata2/proband14/data/mic_running_csv.zip',
#  'Rawdata2/proband14/data/mic_sitting_csv.zip',
#  'Rawdata2/proband14/data/mic_standing_csv.zip',
#  'Rawdata2/proband14/data/mic_walking_csv.zip',
#  'Rawdata2/proband15/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband15/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband15/data/acc_jumping_csv.zip',
#  'Rawdata2/proband15/data/acc_lying_csv.zip',
#  'Rawdata2/proband15/data/acc_running_csv.zip',
#  'Rawdata2/proband15/data/acc_sitting_csv.zip',
#  'Rawdata2/proband15/data/acc_standing_csv.zip',
#  'Rawdata2/proband15/data/acc_walking_csv.zip',
#  'Rawdata2/proband15/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband15/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband15/data/gps_jumping_csv.zip',
#  'Rawdata2/proband15/data/gps_lying_csv.zip',
#  'Rawdata2/proband15/data/gps_running_csv.zip',
#  'Rawdata2/proband15/data/gps_sitting_csv.zip',
#  'Rawdata2/proband15/data/gps_standing_csv.zip',
#  'Rawdata2/proband15/data/gps_walking_csv.zip',
#  'Rawdata2/proband15/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband15/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband15/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband15/data/gyr_lying_csv.zip',
#  'Rawdata2/proband15/data/gyr_running_csv.zip',
#  'Rawdata2/proband15/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband15/data/gyr_standing_csv.zip',
#  'Rawdata2/proband15/data/gyr_walking_csv.zip',
#  'Rawdata2/proband15/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband15/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband15/data/lig_jumping_csv.zip',
#  'Rawdata2/proband15/data/lig_lying_csv.zip',
#  'Rawdata2/proband15/data/lig_running_csv.zip',
#  'Rawdata2/proband15/data/lig_sitting_csv.zip',
#  'Rawdata2/proband15/data/lig_standing_csv.zip',
#  'Rawdata2/proband15/data/lig_walking_csv.zip',
#  'Rawdata2/proband15/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband15/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband15/data/mag_jumping_csv.zip',
#  'Rawdata2/proband15/data/mag_lying_csv.zip',
#  'Rawdata2/proband15/data/mag_running_csv.zip',
#  'Rawdata2/proband15/data/mag_sitting_csv.zip',
#  'Rawdata2/proband15/data/mag_standing_csv.zip',
#  'Rawdata2/proband15/data/mag_walking_csv.zip',
#  'Rawdata2/proband15/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband15/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband15/data/mic_jumping_csv.zip',
#  'Rawdata2/proband15/data/mic_lying_csv.zip',
#  'Rawdata2/proband15/data/mic_running_csv.zip',
#  'Rawdata2/proband15/data/mic_sitting_csv.zip',
#  'Rawdata2/proband15/data/mic_standing_csv.zip',
#  'Rawdata2/proband15/data/mic_walking_csv.zip',
#  'Rawdata2/proband2/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband2/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband2/data/acc_jumping_csv.zip',
#  'Rawdata2/proband2/data/acc_lying_csv.zip',
#  'Rawdata2/proband2/data/acc_running_csv.zip',
#  'Rawdata2/proband2/data/acc_sitting_csv.zip',
#  'Rawdata2/proband2/data/acc_standing_csv.zip',
#  'Rawdata2/proband2/data/acc_walking_csv.zip',
#  'Rawdata2/proband2/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband2/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband2/data/gps_jumping_csv.zip',
#  'Rawdata2/proband2/data/gps_lying_csv.zip',
#  'Rawdata2/proband2/data/gps_running_csv.zip',
#  'Rawdata2/proband2/data/gps_sitting_csv.zip',
#  'Rawdata2/proband2/data/gps_standing_csv.zip',
#  'Rawdata2/proband2/data/gps_walking_csv.zip',
#  'Rawdata2/proband2/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband2/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband2/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband2/data/gyr_lying_csv.zip',
#  'Rawdata2/proband2/data/gyr_running_csv.zip',
#  'Rawdata2/proband2/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband2/data/gyr_standing_csv.zip',
#  'Rawdata2/proband2/data/gyr_walking_csv.zip',
#  'Rawdata2/proband2/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband2/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband2/data/lig_jumping_csv.zip',
#  'Rawdata2/proband2/data/lig_lying_csv.zip',
#  'Rawdata2/proband2/data/lig_running_csv.zip',
#  'Rawdata2/proband2/data/lig_sitting_csv.zip',
#  'Rawdata2/proband2/data/lig_standing_csv.zip',
#  'Rawdata2/proband2/data/lig_walking_csv.zip',
#  'Rawdata2/proband2/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband2/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband2/data/mag_jumping_csv.zip',
#  'Rawdata2/proband2/data/mag_lying_csv.zip',
#  'Rawdata2/proband2/data/mag_running_csv.zip',
#  'Rawdata2/proband2/data/mag_sitting_csv.zip',
#  'Rawdata2/proband2/data/mag_standing_csv.zip',
#  'Rawdata2/proband2/data/mag_walking_csv.zip',
#  'Rawdata2/proband2/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband2/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband2/data/mic_jumping_csv.zip',
#  'Rawdata2/proband2/data/mic_lying_csv.zip',
#  'Rawdata2/proband2/data/mic_running_csv.zip',
#  'Rawdata2/proband2/data/mic_sitting_csv.zip',
#  'Rawdata2/proband2/data/mic_standing_csv.zip',
#  'Rawdata2/proband2/data/mic_walking_csv.zip',
#  'Rawdata2/proband3/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband3/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband3/data/acc_jumping_csv.zip',
#  'Rawdata2/proband3/data/acc_lying_csv.zip',
#  'Rawdata2/proband3/data/acc_running_csv.zip',
#  'Rawdata2/proband3/data/acc_sitting_csv.zip',
#  'Rawdata2/proband3/data/acc_standing_csv.zip',
#  'Rawdata2/proband3/data/acc_walking_csv.zip',
#  'Rawdata2/proband3/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband3/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband3/data/gps_jumping_csv.zip',
#  'Rawdata2/proband3/data/gps_lying_csv.zip',
#  'Rawdata2/proband3/data/gps_running_csv.zip',
#  'Rawdata2/proband3/data/gps_sitting_csv.zip',
#  'Rawdata2/proband3/data/gps_standing_csv.zip',
#  'Rawdata2/proband3/data/gps_walking_csv.zip',
#  'Rawdata2/proband3/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband3/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband3/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband3/data/gyr_lying_csv.zip',
#  'Rawdata2/proband3/data/gyr_running_csv.zip',
#  'Rawdata2/proband3/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband3/data/gyr_standing_csv.zip',
#  'Rawdata2/proband3/data/gyr_walking_csv.zip',
#  'Rawdata2/proband3/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband3/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband3/data/lig_jumping_csv.zip',
#  'Rawdata2/proband3/data/lig_lying_csv.zip',
#  'Rawdata2/proband3/data/lig_running_csv.zip',
#  'Rawdata2/proband3/data/lig_sitting_csv.zip',
#  'Rawdata2/proband3/data/lig_standing_csv.zip',
#  'Rawdata2/proband3/data/lig_walking_csv.zip',
#  'Rawdata2/proband3/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband3/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband3/data/mag_jumping_csv.zip',
#  'Rawdata2/proband3/data/mag_lying_csv.zip',
#  'Rawdata2/proband3/data/mag_running_csv.zip',
#  'Rawdata2/proband3/data/mag_sitting_csv.zip',
#  'Rawdata2/proband3/data/mag_standing_csv.zip',
#  'Rawdata2/proband3/data/mag_walking_csv.zip',
#  'Rawdata2/proband3/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband3/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband3/data/mic_jumping_csv.zip',
#  'Rawdata2/proband3/data/mic_lying_csv.zip',
#  'Rawdata2/proband3/data/mic_running_csv.zip',
#  'Rawdata2/proband3/data/mic_sitting_csv.zip',
#  'Rawdata2/proband3/data/mic_standing_csv.zip',
#  'Rawdata2/proband3/data/mic_walking_csv.zip',
#  'Rawdata2/proband4/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband4/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband4/data/acc_jumping_csv.zip',
#  'Rawdata2/proband4/data/acc_lying_csv.zip',
#  'Rawdata2/proband4/data/acc_running_csv.zip',
#  'Rawdata2/proband4/data/acc_sitting_csv.zip',
#  'Rawdata2/proband4/data/acc_standing_csv.zip',
#  'Rawdata2/proband4/data/acc_walking_csv.zip',
#  'Rawdata2/proband4/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband4/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband4/data/gps_jumping_csv.zip',
#  'Rawdata2/proband4/data/gps_lying_csv.zip',
#  'Rawdata2/proband4/data/gps_running_csv.zip',
#  'Rawdata2/proband4/data/gps_sitting_csv.zip',
#  'Rawdata2/proband4/data/gps_standing_csv.zip',
#  'Rawdata2/proband4/data/gps_walking_csv.zip',
#  'Rawdata2/proband4/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband4/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband4/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband4/data/gyr_lying_csv.zip',
#  'Rawdata2/proband4/data/gyr_running_csv.zip',
#  'Rawdata2/proband4/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband4/data/gyr_standing_csv.zip',
#  'Rawdata2/proband4/data/gyr_walking_csv.zip',
#  'Rawdata2/proband4/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband4/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband4/data/lig_jumping_csv.zip',
#  'Rawdata2/proband4/data/lig_lying_csv.zip',
#  'Rawdata2/proband4/data/lig_running_csv.zip',
#  'Rawdata2/proband4/data/lig_sitting_csv.zip',
#  'Rawdata2/proband4/data/lig_standing_csv.zip',
#  'Rawdata2/proband4/data/lig_walking_csv.zip',
#  'Rawdata2/proband4/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband4/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband4/data/mag_jumping_csv.zip',
#  'Rawdata2/proband4/data/mag_lying_csv.zip',
#  'Rawdata2/proband4/data/mag_running_csv.zip',
#  'Rawdata2/proband4/data/mag_sitting_csv.zip',
#  'Rawdata2/proband4/data/mag_standing_csv.zip',
#  'Rawdata2/proband4/data/mag_walking_csv.zip',
#  'Rawdata2/proband4/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband4/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband4/data/mic_jumping_csv.zip',
#  'Rawdata2/proband4/data/mic_lying_csv.zip',
#  'Rawdata2/proband4/data/mic_running_csv.zip',
#  'Rawdata2/proband4/data/mic_sitting_csv.zip',
#  'Rawdata2/proband4/data/mic_standing_csv.zip',
#  'Rawdata2/proband4/data/mic_walking_csv.zip',
#  'Rawdata2/proband5/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband5/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband5/data/acc_jumping_csv.zip',
#  'Rawdata2/proband5/data/acc_lying_csv.zip',
#  'Rawdata2/proband5/data/acc_running_csv.zip',
#  'Rawdata2/proband5/data/acc_sitting_csv.zip',
#  'Rawdata2/proband5/data/acc_standing_csv.zip',
#  'Rawdata2/proband5/data/acc_walking_csv.zip',
#  'Rawdata2/proband5/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband5/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband5/data/gps_jumping_csv.zip',
#  'Rawdata2/proband5/data/gps_lying_csv.zip',
#  'Rawdata2/proband5/data/gps_running_csv.zip',
#  'Rawdata2/proband5/data/gps_sitting_csv.zip',
#  'Rawdata2/proband5/data/gps_standing_csv.zip',
#  'Rawdata2/proband5/data/gps_walking_csv.zip',
#  'Rawdata2/proband5/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband5/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband5/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband5/data/gyr_lying_csv.zip',
#  'Rawdata2/proband5/data/gyr_running_csv.zip',
#  'Rawdata2/proband5/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband5/data/gyr_standing_csv.zip',
#  'Rawdata2/proband5/data/gyr_walking_csv.zip',
#  'Rawdata2/proband5/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband5/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband5/data/lig_jumping_csv.zip',
#  'Rawdata2/proband5/data/lig_lying_csv.zip',
#  'Rawdata2/proband5/data/lig_running_csv.zip',
#  'Rawdata2/proband5/data/lig_sitting_csv.zip',
#  'Rawdata2/proband5/data/lig_standing_csv.zip',
#  'Rawdata2/proband5/data/lig_walking_csv.zip',
#  'Rawdata2/proband5/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband5/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband5/data/mag_jumping_csv.zip',
#  'Rawdata2/proband5/data/mag_lying_csv.zip',
#  'Rawdata2/proband5/data/mag_running_csv.zip',
#  'Rawdata2/proband5/data/mag_sitting_csv.zip',
#  'Rawdata2/proband5/data/mag_standing_csv.zip',
#  'Rawdata2/proband5/data/mag_walking_csv.zip',
#  'Rawdata2/proband5/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband5/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband5/data/mic_jumping_csv.zip',
#  'Rawdata2/proband5/data/mic_lying_csv.zip',
#  'Rawdata2/proband5/data/mic_running_csv.zip',
#  'Rawdata2/proband5/data/mic_sitting_csv.zip',
#  'Rawdata2/proband5/data/mic_standing_csv.zip',
#  'Rawdata2/proband5/data/mic_walking_csv.zip',
#  'Rawdata2/proband6/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband6/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband6/data/acc_jumping_csv.zip',
#  'Rawdata2/proband6/data/acc_lying_csv.zip',
#  'Rawdata2/proband6/data/acc_running_csv.zip',
#  'Rawdata2/proband6/data/acc_sitting_csv.zip',
#  'Rawdata2/proband6/data/acc_standing_csv.zip',
#  'Rawdata2/proband6/data/acc_walking_csv.zip',
#  'Rawdata2/proband6/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband6/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband6/data/gps_jumping_csv.zip',
#  'Rawdata2/proband6/data/gps_lying_csv.zip',
#  'Rawdata2/proband6/data/gps_running_csv.zip',
#  'Rawdata2/proband6/data/gps_sitting_csv.zip',
#  'Rawdata2/proband6/data/gps_standing_csv.zip',
#  'Rawdata2/proband6/data/gps_walking_csv.zip',
#  'Rawdata2/proband6/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband6/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband6/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband6/data/gyr_lying_csv.zip',
#  'Rawdata2/proband6/data/gyr_running_csv.zip',
#  'Rawdata2/proband6/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband6/data/gyr_standing_csv.zip',
#  'Rawdata2/proband6/data/gyr_walking_csv.zip',
#  'Rawdata2/proband6/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband6/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband6/data/lig_jumping_csv.zip',
#  'Rawdata2/proband6/data/lig_lying_csv.zip',
#  'Rawdata2/proband6/data/lig_running_csv.zip',
#  'Rawdata2/proband6/data/lig_sitting_csv.zip',
#  'Rawdata2/proband6/data/lig_standing_csv.zip',
#  'Rawdata2/proband6/data/lig_walking_csv.zip',
#  'Rawdata2/proband6/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband6/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband6/data/mag_jumping_csv.zip',
#  'Rawdata2/proband6/data/mag_lying_csv.zip',
#  'Rawdata2/proband6/data/mag_running_csv.zip',
#  'Rawdata2/proband6/data/mag_sitting_csv.zip',
#  'Rawdata2/proband6/data/mag_standing_csv.zip',
#  'Rawdata2/proband6/data/mag_walking_csv.zip',
#  'Rawdata2/proband6/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband6/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband6/data/mic_jumping_csv.zip',
#  'Rawdata2/proband6/data/mic_lying_csv.zip',
#  'Rawdata2/proband6/data/mic_running_csv.zip',
#  'Rawdata2/proband6/data/mic_sitting_csv.zip',
#  'Rawdata2/proband6/data/mic_standing_csv.zip',
#  'Rawdata2/proband6/data/mic_walking_csv.zip',
#  'Rawdata2/proband7/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband7/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband7/data/acc_jumping_csv.zip',
#  'Rawdata2/proband7/data/acc_lying_csv.zip',
#  'Rawdata2/proband7/data/acc_running_csv.zip',
#  'Rawdata2/proband7/data/acc_sitting_csv.zip',
#  'Rawdata2/proband7/data/acc_standing_csv.zip',
#  'Rawdata2/proband7/data/acc_walking_csv.zip',
#  'Rawdata2/proband7/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband7/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband7/data/gps_jumping_csv.zip',
#  'Rawdata2/proband7/data/gps_lying_csv.zip',
#  'Rawdata2/proband7/data/gps_running_csv.zip',
#  'Rawdata2/proband7/data/gps_sitting_csv.zip',
#  'Rawdata2/proband7/data/gps_standing_csv.zip',
#  'Rawdata2/proband7/data/gps_walking_csv.zip',
#  'Rawdata2/proband7/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband7/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband7/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband7/data/gyr_lying_csv.zip',
#  'Rawdata2/proband7/data/gyr_running_csv.zip',
#  'Rawdata2/proband7/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband7/data/gyr_standing_csv.zip',
#  'Rawdata2/proband7/data/gyr_walking_csv.zip',
#  'Rawdata2/proband7/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband7/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband7/data/lig_jumping_csv.zip',
#  'Rawdata2/proband7/data/lig_lying_csv.zip',
#  'Rawdata2/proband7/data/lig_running_csv.zip',
#  'Rawdata2/proband7/data/lig_sitting_csv.zip',
#  'Rawdata2/proband7/data/lig_standing_csv.zip',
#  'Rawdata2/proband7/data/lig_walking_csv.zip',
#  'Rawdata2/proband7/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband7/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband7/data/mag_jumping_csv.zip',
#  'Rawdata2/proband7/data/mag_lying_csv.zip',
#  'Rawdata2/proband7/data/mag_running_csv.zip',
#  'Rawdata2/proband7/data/mag_sitting_csv.zip',
#  'Rawdata2/proband7/data/mag_standing_csv.zip',
#  'Rawdata2/proband7/data/mag_walking_csv.zip',
#  'Rawdata2/proband7/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband7/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband7/data/mic_jumping_csv.zip',
#  'Rawdata2/proband7/data/mic_lying_csv.zip',
#  'Rawdata2/proband7/data/mic_running_csv.zip',
#  'Rawdata2/proband7/data/mic_sitting_csv.zip',
#  'Rawdata2/proband7/data/mic_standing_csv.zip',
#  'Rawdata2/proband7/data/mic_walking_csv.zip',
#  'Rawdata2/proband8/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband8/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband8/data/acc_jumping_csv.zip',
#  'Rawdata2/proband8/data/acc_lying_csv.zip',
#  'Rawdata2/proband8/data/acc_running_csv.zip',
#  'Rawdata2/proband8/data/acc_sitting_csv.zip',
#  'Rawdata2/proband8/data/acc_standing_csv.zip',
#  'Rawdata2/proband8/data/acc_walking_csv.zip',
#  'Rawdata2/proband8/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband8/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband8/data/gps_lying_csv.zip',
#  'Rawdata2/proband8/data/gps_sitting_csv.zip',
#  'Rawdata2/proband8/data/gps_standing_csv.zip',
#  'Rawdata2/proband8/data/gps_walking_csv.zip',
#  'Rawdata2/proband8/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband8/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband8/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband8/data/gyr_lying_csv.zip',
#  'Rawdata2/proband8/data/gyr_running_csv.zip',
#  'Rawdata2/proband8/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband8/data/gyr_standing_csv.zip',
#  'Rawdata2/proband8/data/gyr_walking_csv.zip',
#  'Rawdata2/proband8/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband8/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband8/data/lig_jumping_csv.zip',
#  'Rawdata2/proband8/data/lig_lying_csv.zip',
#  'Rawdata2/proband8/data/lig_running_csv.zip',
#  'Rawdata2/proband8/data/lig_sitting_csv.zip',
#  'Rawdata2/proband8/data/lig_standing_csv.zip',
#  'Rawdata2/proband8/data/lig_walking_csv.zip',
#  'Rawdata2/proband8/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband8/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband8/data/mag_jumping_csv.zip',
#  'Rawdata2/proband8/data/mag_lying_csv.zip',
#  'Rawdata2/proband8/data/mag_running_csv.zip',
#  'Rawdata2/proband8/data/mag_sitting_csv.zip',
#  'Rawdata2/proband8/data/mag_standing_csv.zip',
#  'Rawdata2/proband8/data/mag_walking_csv.zip',
#  'Rawdata2/proband8/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband8/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband8/data/mic_jumping_csv.zip',
#  'Rawdata2/proband8/data/mic_lying_csv.zip',
#  'Rawdata2/proband8/data/mic_running_csv.zip',
#  'Rawdata2/proband8/data/mic_sitting_csv.zip',
#  'Rawdata2/proband8/data/mic_standing_csv.zip',
#  'Rawdata2/proband8/data/mic_walking_csv.zip',
#  'Rawdata2/proband9/data/acc_climbingdown_csv.zip',
#  'Rawdata2/proband9/data/acc_climbingup_csv.zip',
#  'Rawdata2/proband9/data/acc_jumping_csv.zip',
#  'Rawdata2/proband9/data/acc_lying_csv.zip',
#  'Rawdata2/proband9/data/acc_running_csv.zip',
#  'Rawdata2/proband9/data/acc_sitting_csv.zip',
#  'Rawdata2/proband9/data/acc_standing_csv.zip',
#  'Rawdata2/proband9/data/acc_walking_csv.zip',
#  'Rawdata2/proband9/data/gps_climbingdown_csv.zip',
#  'Rawdata2/proband9/data/gps_climbingup_csv.zip',
#  'Rawdata2/proband9/data/gps_jumping_csv.zip',
#  'Rawdata2/proband9/data/gps_lying_csv.zip',
#  'Rawdata2/proband9/data/gps_running_csv.zip',
#  'Rawdata2/proband9/data/gps_sitting_csv.zip',
#  'Rawdata2/proband9/data/gps_standing_csv.zip',
#  'Rawdata2/proband9/data/gps_walking_csv.zip',
#  'Rawdata2/proband9/data/gyr_climbingdown_csv.zip',
#  'Rawdata2/proband9/data/gyr_climbingup_csv.zip',
#  'Rawdata2/proband9/data/gyr_jumping_csv.zip',
#  'Rawdata2/proband9/data/gyr_lying_csv.zip',
#  'Rawdata2/proband9/data/gyr_running_csv.zip',
#  'Rawdata2/proband9/data/gyr_sitting_csv.zip',
#  'Rawdata2/proband9/data/gyr_standing_csv.zip',
#  'Rawdata2/proband9/data/gyr_walking_csv.zip',
#  'Rawdata2/proband9/data/lig_climbingdown_csv.zip',
#  'Rawdata2/proband9/data/lig_climbingup_csv.zip',
#  'Rawdata2/proband9/data/lig_jumping_csv.zip',
#  'Rawdata2/proband9/data/lig_lying_csv.zip',
#  'Rawdata2/proband9/data/lig_running_csv.zip',
#  'Rawdata2/proband9/data/lig_sitting_csv.zip',
#  'Rawdata2/proband9/data/lig_standing_csv.zip',
#  'Rawdata2/proband9/data/lig_walking_csv.zip',
#  'Rawdata2/proband9/data/mag_climbingdown_csv.zip',
#  'Rawdata2/proband9/data/mag_climbingup_csv.zip',
#  'Rawdata2/proband9/data/mag_jumping_csv.zip',
#  'Rawdata2/proband9/data/mag_lying_csv.zip',
#  'Rawdata2/proband9/data/mag_running_csv.zip',
#  'Rawdata2/proband9/data/mag_sitting_csv.zip',
#  'Rawdata2/proband9/data/mag_standing_csv.zip',
#  'Rawdata2/proband9/data/mag_walking_csv.zip',
#  'Rawdata2/proband9/data/mic_climbingdown_csv.zip',
#  'Rawdata2/proband9/data/mic_climbingup_csv.zip',
#  'Rawdata2/proband9/data/mic_jumping_csv.zip',
#  'Rawdata2/proband9/data/mic_lying_csv.zip',
#  'Rawdata2/proband9/data/mic_running_csv.zip',
#  'Rawdata2/proband9/data/mic_sitting_csv.zip',
#  'Rawdata2/proband9/data/mic_standing_csv.zip',
#  'Rawdata2/proband9/data/mic_walking_csv.zip']

# %% [markdown]
# #### Zipfile handling
# function 'openzip' has as input a zipfile path and SubjectNr. The function extract all csv files from zip, removes the readMe text file and retrieves info from file name:
# * Sensory_type
# * Activity
# * Body-position
#
# As output the function generates a list with csv file's and list of labels that stick with that csv file.

# %%
#input zipfilename, output list of csv files
def openzip(file_name, subject_id):
    labellist = []
    
    with ZipFile(file_name, 'r') as zip:
        csvlist = zip.namelist()
    
        if 'readMe' in csvlist:
            csvlist.remove('readMe')

        for name in csvlist:
            sublabellist = []
            zip.extract(name)

            #get labels
            templist = name.split("_")
            sensory_type = templist[0]
            activity = templist[1]
            body_position = templist[2].split(".")
            body_position = body_position[0]

            #create sublist in csvlist per csv file for labels
            sublabellist.append(sensory_type)
            sublabellist.append(activity)
            sublabellist.append(body_position)

            labellist.append(sublabellist)

        return csvlist, labellist

# %% [markdown]
# The 'Create_dataframe' function has as input the csvfile name, the according labellist and a count the nr of dataframe that is created. Since we merging per sensor-type, activity and subject the attributes. Meaning that we only need the Subject_ID, sensor-type and activty column 1 time. <br>
#
# Further, the column attributes name will be changed according the body-position the data is from
#
# With as output a dataframe.

# %%
def create_dataframe(csvfile, labellist, count):
    df = pd.read_csv(csv)
    
    if count == 0:
        #add columns to df using labellist
        df['Subject ID'] = subject_ID
        df['Sensor-type'] = labellist[count][0]
        df['Activity'] = labellist[count][1]
          
    body_position = labellist[count][2]  
        
    df = df.rename(columns=
                {'attr_x': 'attr_x_' + body_position,
                 'attr_y': 'attr_y_' + body_position,
                 'attr_z': 'attr_z_' + body_position})
    return df

# %% [markdown]
# The main code path down below, retrieves for each zip file from which subject it is and generates a csv file containing the merged dataframe of each sensor-type, activity, subject combination.

# %%
for path in paths_list:
    #retrieve labels
    templist = path.split("/")
    templist2 = templist[3].split("_")

    #get subject label
    subject_ID = templist[1].replace("proband", '')
    
    print("PATH: " + path + " SUBJECT: " + subject_ID)
    
    count = 0
    csvlist, labellist = openzip(path, subject_ID)
    
    for csv in csvlist:
        
        if count == 0:
            #first_df
            df1 = create_dataframe(csv, labellist, count)
            #print('START dataframe    ' + csv)
        else:
            #merge
            df2 = create_dataframe(csv, labellist, count)
            merged_df = df1.merge(df2, on='id')
            df1 = merged_df
            #print('MERGE COMPLETE    ' + csv)
        
        count += 1
        
        #remove csv after use
        os.remove(csv)  
        
    #temporary csv
    filename = subject_ID + '_' + labellist[0][0] + '_' + labellist[0][1] + '_' + 'Merged.csv'
    print("MERGE FILE COMPLETE: " + filename)
    
    merged_df.to_csv(filename, index=True)
# Out:
# PATH: Rawdata2/proband1/data/acc_climbingdown_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_acc_climbingdown_Merged.csv
# PATH: Rawdata2/proband1/data/acc_climbingup_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_acc_climbingup_Merged.csv
# PATH: Rawdata2/proband1/data/acc_jumping_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_acc_jumping_Merged.csv
# PATH: Rawdata2/proband1/data/acc_lying_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_acc_lying_Merged.csv
# PATH: Rawdata2/proband1/data/acc_running_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_acc_running_Merged.csv
# PATH: Rawdata2/proband1/data/acc_sitting_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_acc_sitting_Merged.csv
# PATH: Rawdata2/proband1/data/acc_standing_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_acc_standing_Merged.csv
# PATH: Rawdata2/proband1/data/acc_walking_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_acc_walking_Merged.csv
# PATH: Rawdata2/proband1/data/gps_climbingdown_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_GPS_climbingdown_Merged.csv
# PATH: Rawdata2/proband1/data/gps_climbingup_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_GPS_climbingup_Merged.csv
# PATH: Rawdata2/proband1/data/gps_jumping_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_GPS_jumping_Merged.csv
# PATH: Rawdata2/proband1/data/gps_lying_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_GPS_lying_Merged.csv
# PATH: Rawdata2/proband1/data/gps_running_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_GPS_running_Merged.csv
# PATH: Rawdata2/proband1/data/gps_sitting_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_GPS_sitting_Merged.csv
# PATH: Rawdata2/proband1/data/gps_standing_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_GPS_standing_Merged.csv
# PATH: Rawdata2/proband1/data/gps_walking_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_GPS_walking_Merged.csv
# PATH: Rawdata2/proband1/data/gyr_climbingdown_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Gyroscope_climbingdown_Merged.csv
# PATH: Rawdata2/proband1/data/gyr_climbingup_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Gyroscope_climbingup_Merged.csv
# PATH: Rawdata2/proband1/data/gyr_jumping_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Gyroscope_jumping_Merged.csv
# PATH: Rawdata2/proband1/data/gyr_lying_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Gyroscope_lying_Merged.csv
# PATH: Rawdata2/proband1/data/gyr_running_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Gyroscope_running_Merged.csv
# PATH: Rawdata2/proband1/data/gyr_sitting_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Gyroscope_sitting_Merged.csv
# PATH: Rawdata2/proband1/data/gyr_standing_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Gyroscope_standing_Merged.csv
# PATH: Rawdata2/proband1/data/gyr_walking_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Gyroscope_walking_Merged.csv
# PATH: Rawdata2/proband1/data/lig_climbingdown_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Light_climbingdown_Merged.csv
# PATH: Rawdata2/proband1/data/lig_climbingup_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Light_climbingup_Merged.csv
# PATH: Rawdata2/proband1/data/lig_jumping_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Light_jumping_Merged.csv
# PATH: Rawdata2/proband1/data/lig_lying_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Light_lying_Merged.csv
# PATH: Rawdata2/proband1/data/lig_running_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Light_running_Merged.csv
# PATH: Rawdata2/proband1/data/lig_sitting_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Light_sitting_Merged.csv
# PATH: Rawdata2/proband1/data/lig_standing_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Light_standing_Merged.csv
# PATH: Rawdata2/proband1/data/lig_walking_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Light_walking_Merged.csv
# PATH: Rawdata2/proband1/data/mag_climbingdown_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_MagneticField_climbingdown_Merged.csv
# PATH: Rawdata2/proband1/data/mag_climbingup_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_MagneticField_climbingup_Merged.csv
# PATH: Rawdata2/proband1/data/mag_jumping_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_MagneticField_jumping_Merged.csv
# PATH: Rawdata2/proband1/data/mag_lying_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_MagneticField_lying_Merged.csv
# PATH: Rawdata2/proband1/data/mag_running_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_MagneticField_running_Merged.csv
# PATH: Rawdata2/proband1/data/mag_sitting_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_MagneticField_sitting_Merged.csv
# PATH: Rawdata2/proband1/data/mag_standing_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_MagneticField_standing_Merged.csv
# PATH: Rawdata2/proband1/data/mag_walking_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_MagneticField_walking_Merged.csv
# PATH: Rawdata2/proband1/data/mic_climbingdown_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Microphone_climbingdown_Merged.csv
# PATH: Rawdata2/proband1/data/mic_climbingup_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Microphone_climbingup_Merged.csv
# PATH: Rawdata2/proband1/data/mic_jumping_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Microphone_jumping_Merged.csv
# PATH: Rawdata2/proband1/data/mic_lying_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Microphone_lying_Merged.csv
# PATH: Rawdata2/proband1/data/mic_running_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Microphone_running_Merged.csv
# PATH: Rawdata2/proband1/data/mic_sitting_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Microphone_sitting_Merged.csv
# PATH: Rawdata2/proband1/data/mic_standing_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Microphone_standing_Merged.csv
# PATH: Rawdata2/proband1/data/mic_walking_csv.zip SUBJECT: 1
# MERGE FILE COMPLETE: 1_Microphone_walking_Merged.csv
# PATH: Rawdata2/proband10/data/acc_climbingdown_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_acc_climbingdown_Merged.csv
# PATH: Rawdata2/proband10/data/acc_climbingup_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_acc_climbingup_Merged.csv
# PATH: Rawdata2/proband10/data/acc_jumping_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_acc_jumping_Merged.csv
# PATH: Rawdata2/proband10/data/acc_lying_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_acc_lying_Merged.csv
# PATH: Rawdata2/proband10/data/acc_running_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_acc_running_Merged.csv
# PATH: Rawdata2/proband10/data/acc_sitting_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_acc_sitting_Merged.csv
# PATH: Rawdata2/proband10/data/acc_standing_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_acc_standing_Merged.csv
# PATH: Rawdata2/proband10/data/acc_walking_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_acc_walking_Merged.csv
# PATH: Rawdata2/proband10/data/gps_climbingdown_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_GPS_climbingdown_Merged.csv
# PATH: Rawdata2/proband10/data/gps_climbingup_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_GPS_climbingup_Merged.csv
# PATH: Rawdata2/proband10/data/gps_jumping_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_GPS_jumping_Merged.csv
# PATH: Rawdata2/proband10/data/gps_lying_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_GPS_lying_Merged.csv
# PATH: Rawdata2/proband10/data/gps_running_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_GPS_running_Merged.csv
# PATH: Rawdata2/proband10/data/gps_sitting_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_GPS_sitting_Merged.csv
# PATH: Rawdata2/proband10/data/gps_standing_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_GPS_standing_Merged.csv
# PATH: Rawdata2/proband10/data/gps_walking_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_GPS_walking_Merged.csv
# PATH: Rawdata2/proband10/data/gyr_climbingdown_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Gyroscope_climbingdown_Merged.csv
# PATH: Rawdata2/proband10/data/gyr_climbingup_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Gyroscope_climbingup_Merged.csv
# PATH: Rawdata2/proband10/data/gyr_jumping_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Gyroscope_jumping_Merged.csv
# PATH: Rawdata2/proband10/data/gyr_lying_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Gyroscope_lying_Merged.csv
# PATH: Rawdata2/proband10/data/gyr_running_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Gyroscope_running_Merged.csv
# PATH: Rawdata2/proband10/data/gyr_sitting_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Gyroscope_sitting_Merged.csv
# PATH: Rawdata2/proband10/data/gyr_standing_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Gyroscope_standing_Merged.csv
# PATH: Rawdata2/proband10/data/gyr_walking_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Gyroscope_walking_Merged.csv
# PATH: Rawdata2/proband10/data/lig_climbingdown_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Light_climbingdown_Merged.csv
# PATH: Rawdata2/proband10/data/lig_climbingup_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Light_climbingup_Merged.csv
# PATH: Rawdata2/proband10/data/lig_jumping_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Light_jumping_Merged.csv
# PATH: Rawdata2/proband10/data/lig_lying_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Light_lying_Merged.csv
# PATH: Rawdata2/proband10/data/lig_running_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Light_running_Merged.csv
# PATH: Rawdata2/proband10/data/lig_sitting_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Light_sitting_Merged.csv
# PATH: Rawdata2/proband10/data/lig_standing_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Light_standing_Merged.csv
# PATH: Rawdata2/proband10/data/lig_walking_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Light_walking_Merged.csv
# PATH: Rawdata2/proband10/data/mag_climbingdown_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_MagneticField_climbingdown_Merged.csv
# PATH: Rawdata2/proband10/data/mag_climbingup_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_MagneticField_climbingup_Merged.csv
# PATH: Rawdata2/proband10/data/mag_jumping_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_MagneticField_jumping_Merged.csv
# PATH: Rawdata2/proband10/data/mag_lying_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_MagneticField_lying_Merged.csv
# PATH: Rawdata2/proband10/data/mag_running_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_MagneticField_running_Merged.csv
# PATH: Rawdata2/proband10/data/mag_sitting_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_MagneticField_sitting_Merged.csv
# PATH: Rawdata2/proband10/data/mag_standing_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_MagneticField_standing_Merged.csv
# PATH: Rawdata2/proband10/data/mag_walking_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_MagneticField_walking_Merged.csv
# PATH: Rawdata2/proband10/data/mic_climbingdown_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Microphone_climbingdown_Merged.csv
# PATH: Rawdata2/proband10/data/mic_climbingup_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Microphone_climbingup_Merged.csv
# PATH: Rawdata2/proband10/data/mic_jumping_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Microphone_jumping_Merged.csv
# PATH: Rawdata2/proband10/data/mic_lying_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Microphone_lying_Merged.csv
# PATH: Rawdata2/proband10/data/mic_running_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Microphone_running_Merged.csv
# PATH: Rawdata2/proband10/data/mic_sitting_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Microphone_sitting_Merged.csv
# PATH: Rawdata2/proband10/data/mic_standing_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Microphone_standing_Merged.csv
# PATH: Rawdata2/proband10/data/mic_walking_csv.zip SUBJECT: 10
# MERGE FILE COMPLETE: 10_Microphone_walking_Merged.csv
# PATH: Rawdata2/proband11/data/acc_climbingdown_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_acc_climbingdown_Merged.csv
# PATH: Rawdata2/proband11/data/acc_climbingup_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_acc_climbingup_Merged.csv
# PATH: Rawdata2/proband11/data/acc_jumping_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_acc_jumping_Merged.csv
# PATH: Rawdata2/proband11/data/acc_lying_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_acc_lying_Merged.csv
# PATH: Rawdata2/proband11/data/acc_running_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_acc_running_Merged.csv
# PATH: Rawdata2/proband11/data/acc_sitting_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_acc_sitting_Merged.csv
# PATH: Rawdata2/proband11/data/acc_standing_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_acc_standing_Merged.csv
# PATH: Rawdata2/proband11/data/acc_walking_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_acc_walking_Merged.csv
# PATH: Rawdata2/proband11/data/gps_climbingdown_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_GPS_climbingdown_Merged.csv
# PATH: Rawdata2/proband11/data/gps_climbingup_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_GPS_climbingup_Merged.csv
# PATH: Rawdata2/proband11/data/gps_jumping_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_GPS_jumping_Merged.csv
# PATH: Rawdata2/proband11/data/gps_lying_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_GPS_lying_Merged.csv
# PATH: Rawdata2/proband11/data/gps_running_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_GPS_running_Merged.csv
# PATH: Rawdata2/proband11/data/gps_sitting_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_GPS_sitting_Merged.csv
# PATH: Rawdata2/proband11/data/gps_standing_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_GPS_standing_Merged.csv
# PATH: Rawdata2/proband11/data/gps_walking_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_GPS_walking_Merged.csv
# PATH: Rawdata2/proband11/data/gyr_climbingdown_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Gyroscope_climbingdown_Merged.csv
# PATH: Rawdata2/proband11/data/gyr_climbingup_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Gyroscope_climbingup_Merged.csv
# PATH: Rawdata2/proband11/data/gyr_jumping_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Gyroscope_jumping_Merged.csv
# PATH: Rawdata2/proband11/data/gyr_lying_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Gyroscope_lying_Merged.csv
# PATH: Rawdata2/proband11/data/gyr_running_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Gyroscope_running_Merged.csv
# PATH: Rawdata2/proband11/data/gyr_sitting_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Gyroscope_sitting_Merged.csv
# PATH: Rawdata2/proband11/data/gyr_standing_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Gyroscope_standing_Merged.csv
# PATH: Rawdata2/proband11/data/gyr_walking_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Gyroscope_walking_Merged.csv
# PATH: Rawdata2/proband11/data/lig_climbingdown_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Light_climbingdown_Merged.csv
# PATH: Rawdata2/proband11/data/lig_climbingup_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Light_climbingup_Merged.csv
# PATH: Rawdata2/proband11/data/lig_jumping_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Light_jumping_Merged.csv
# PATH: Rawdata2/proband11/data/lig_lying_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Light_lying_Merged.csv
# PATH: Rawdata2/proband11/data/lig_running_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Light_running_Merged.csv
# PATH: Rawdata2/proband11/data/lig_sitting_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Light_sitting_Merged.csv
# PATH: Rawdata2/proband11/data/lig_standing_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Light_standing_Merged.csv
# PATH: Rawdata2/proband11/data/lig_walking_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Light_walking_Merged.csv
# PATH: Rawdata2/proband11/data/mag_climbingdown_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_MagneticField_climbingdown_Merged.csv
# PATH: Rawdata2/proband11/data/mag_climbingup_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_MagneticField_climbingup_Merged.csv
# PATH: Rawdata2/proband11/data/mag_jumping_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_MagneticField_jumping_Merged.csv
# PATH: Rawdata2/proband11/data/mag_lying_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_MagneticField_lying_Merged.csv
# PATH: Rawdata2/proband11/data/mag_running_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_MagneticField_running_Merged.csv
# PATH: Rawdata2/proband11/data/mag_sitting_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_MagneticField_sitting_Merged.csv
# PATH: Rawdata2/proband11/data/mag_standing_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_MagneticField_standing_Merged.csv
# PATH: Rawdata2/proband11/data/mag_walking_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_MagneticField_walking_Merged.csv
# PATH: Rawdata2/proband11/data/mic_climbingdown_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Microphone_climbingdown_Merged.csv
# PATH: Rawdata2/proband11/data/mic_climbingup_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Microphone_climbingup_Merged.csv
# PATH: Rawdata2/proband11/data/mic_jumping_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Microphone_jumping_Merged.csv
# PATH: Rawdata2/proband11/data/mic_lying_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Microphone_lying_Merged.csv
# PATH: Rawdata2/proband11/data/mic_running_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Microphone_running_Merged.csv
# PATH: Rawdata2/proband11/data/mic_sitting_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Microphone_sitting_Merged.csv
# PATH: Rawdata2/proband11/data/mic_standing_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Microphone_standing_Merged.csv
# PATH: Rawdata2/proband11/data/mic_walking_csv.zip SUBJECT: 11
# MERGE FILE COMPLETE: 11_Microphone_walking_Merged.csv
# PATH: Rawdata2/proband12/data/acc_climbingdown_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_acc_climbingdown_Merged.csv
# PATH: Rawdata2/proband12/data/acc_climbingup_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_acc_climbingup_Merged.csv
# PATH: Rawdata2/proband12/data/acc_jumping_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_acc_jumping_Merged.csv
# PATH: Rawdata2/proband12/data/acc_lying_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_acc_lying_Merged.csv
# PATH: Rawdata2/proband12/data/acc_running_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_acc_running_Merged.csv
# PATH: Rawdata2/proband12/data/acc_sitting_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_acc_sitting_Merged.csv
# PATH: Rawdata2/proband12/data/acc_standing_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_acc_standing_Merged.csv
# PATH: Rawdata2/proband12/data/acc_walking_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_acc_walking_Merged.csv
# PATH: Rawdata2/proband12/data/gps_climbingdown_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_GPS_climbingdown_Merged.csv
# PATH: Rawdata2/proband12/data/gps_climbingup_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_GPS_climbingup_Merged.csv
# PATH: Rawdata2/proband12/data/gps_jumping_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_GPS_jumping_Merged.csv
# PATH: Rawdata2/proband12/data/gps_lying_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_GPS_lying_Merged.csv
# PATH: Rawdata2/proband12/data/gps_running_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_GPS_running_Merged.csv
# PATH: Rawdata2/proband12/data/gps_sitting_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_GPS_sitting_Merged.csv
# PATH: Rawdata2/proband12/data/gps_standing_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_GPS_standing_Merged.csv
# PATH: Rawdata2/proband12/data/gps_walking_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_GPS_walking_Merged.csv
# PATH: Rawdata2/proband12/data/gyr_climbingdown_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Gyroscope_climbingdown_Merged.csv
# PATH: Rawdata2/proband12/data/gyr_climbingup_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Gyroscope_climbingup_Merged.csv
# PATH: Rawdata2/proband12/data/gyr_jumping_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Gyroscope_jumping_Merged.csv
# PATH: Rawdata2/proband12/data/gyr_lying_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Gyroscope_lying_Merged.csv
# PATH: Rawdata2/proband12/data/gyr_running_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Gyroscope_running_Merged.csv
# PATH: Rawdata2/proband12/data/gyr_sitting_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Gyroscope_sitting_Merged.csv
# PATH: Rawdata2/proband12/data/gyr_standing_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Gyroscope_standing_Merged.csv
# PATH: Rawdata2/proband12/data/gyr_walking_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Gyroscope_walking_Merged.csv
# PATH: Rawdata2/proband12/data/lig_climbingdown_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Light_climbingdown_Merged.csv
# PATH: Rawdata2/proband12/data/lig_climbingup_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Light_climbingup_Merged.csv
# PATH: Rawdata2/proband12/data/lig_jumping_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Light_jumping_Merged.csv
# PATH: Rawdata2/proband12/data/lig_lying_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Light_lying_Merged.csv
# PATH: Rawdata2/proband12/data/lig_running_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Light_running_Merged.csv
# PATH: Rawdata2/proband12/data/lig_sitting_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Light_sitting_Merged.csv
# PATH: Rawdata2/proband12/data/lig_standing_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Light_standing_Merged.csv
# PATH: Rawdata2/proband12/data/lig_walking_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Light_walking_Merged.csv
# PATH: Rawdata2/proband12/data/mag_climbingdown_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_MagneticField_climbingdown_Merged.csv
# PATH: Rawdata2/proband12/data/mag_climbingup_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_MagneticField_climbingup_Merged.csv
# PATH: Rawdata2/proband12/data/mag_jumping_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_MagneticField_jumping_Merged.csv
# PATH: Rawdata2/proband12/data/mag_lying_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_MagneticField_lying_Merged.csv
# PATH: Rawdata2/proband12/data/mag_running_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_MagneticField_running_Merged.csv
# PATH: Rawdata2/proband12/data/mag_sitting_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_MagneticField_sitting_Merged.csv
# PATH: Rawdata2/proband12/data/mag_standing_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_MagneticField_standing_Merged.csv
# PATH: Rawdata2/proband12/data/mag_walking_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_MagneticField_walking_Merged.csv
# PATH: Rawdata2/proband12/data/mic_climbingdown_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Microphone_climbingdown_Merged.csv
# PATH: Rawdata2/proband12/data/mic_climbingup_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Microphone_climbingup_Merged.csv
# PATH: Rawdata2/proband12/data/mic_jumping_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Microphone_jumping_Merged.csv
# PATH: Rawdata2/proband12/data/mic_lying_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Microphone_lying_Merged.csv
# PATH: Rawdata2/proband12/data/mic_running_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Microphone_running_Merged.csv
# PATH: Rawdata2/proband12/data/mic_sitting_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Microphone_sitting_Merged.csv
# PATH: Rawdata2/proband12/data/mic_standing_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Microphone_standing_Merged.csv
# PATH: Rawdata2/proband12/data/mic_walking_csv.zip SUBJECT: 12
# MERGE FILE COMPLETE: 12_Microphone_walking_Merged.csv
# PATH: Rawdata2/proband13/data/acc_climbingdown_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_acc_climbingdown_Merged.csv
# PATH: Rawdata2/proband13/data/acc_climbingup_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_acc_climbingup_Merged.csv
# PATH: Rawdata2/proband13/data/acc_jumping_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_acc_jumping_Merged.csv
# PATH: Rawdata2/proband13/data/acc_lying_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_acc_lying_Merged.csv
# PATH: Rawdata2/proband13/data/acc_running_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_acc_running_Merged.csv
# PATH: Rawdata2/proband13/data/acc_sitting_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_acc_sitting_Merged.csv
# PATH: Rawdata2/proband13/data/acc_standing_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_acc_standing_Merged.csv
# PATH: Rawdata2/proband13/data/acc_walking_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_acc_walking_Merged.csv
# PATH: Rawdata2/proband13/data/gps_climbingdown_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_GPS_climbingdown_Merged.csv
# PATH: Rawdata2/proband13/data/gps_climbingup_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_GPS_climbingup_Merged.csv
# PATH: Rawdata2/proband13/data/gps_jumping_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_GPS_jumping_Merged.csv
# PATH: Rawdata2/proband13/data/gps_lying_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_GPS_lying_Merged.csv
# PATH: Rawdata2/proband13/data/gps_running_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_GPS_running_Merged.csv
# PATH: Rawdata2/proband13/data/gps_sitting_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_GPS_sitting_Merged.csv
# PATH: Rawdata2/proband13/data/gps_standing_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_GPS_standing_Merged.csv
# PATH: Rawdata2/proband13/data/gps_walking_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_GPS_walking_Merged.csv
# PATH: Rawdata2/proband13/data/gyr_climbingdown_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Gyroscope_climbingdown_Merged.csv
# PATH: Rawdata2/proband13/data/gyr_climbingup_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Gyroscope_climbingup_Merged.csv
# PATH: Rawdata2/proband13/data/gyr_jumping_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Gyroscope_jumping_Merged.csv
# PATH: Rawdata2/proband13/data/gyr_lying_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Gyroscope_lying_Merged.csv
# PATH: Rawdata2/proband13/data/gyr_running_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Gyroscope_running_Merged.csv
# PATH: Rawdata2/proband13/data/gyr_sitting_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Gyroscope_sitting_Merged.csv
# PATH: Rawdata2/proband13/data/gyr_standing_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Gyroscope_standing_Merged.csv
# PATH: Rawdata2/proband13/data/gyr_walking_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Gyroscope_walking_Merged.csv
# PATH: Rawdata2/proband13/data/lig_climbingdown_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Light_climbingdown_Merged.csv
# PATH: Rawdata2/proband13/data/lig_climbingup_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Light_climbingup_Merged.csv
# PATH: Rawdata2/proband13/data/lig_jumping_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Light_jumping_Merged.csv
# PATH: Rawdata2/proband13/data/lig_lying_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Light_lying_Merged.csv
# PATH: Rawdata2/proband13/data/lig_running_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Light_running_Merged.csv
# PATH: Rawdata2/proband13/data/lig_sitting_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Light_sitting_Merged.csv
# PATH: Rawdata2/proband13/data/lig_standing_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Light_standing_Merged.csv
# PATH: Rawdata2/proband13/data/lig_walking_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Light_walking_Merged.csv
# PATH: Rawdata2/proband13/data/mag_climbingdown_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_MagneticField_climbingdown_Merged.csv
# PATH: Rawdata2/proband13/data/mag_climbingup_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_MagneticField_climbingup_Merged.csv
# PATH: Rawdata2/proband13/data/mag_jumping_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_MagneticField_jumping_Merged.csv
# PATH: Rawdata2/proband13/data/mag_lying_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_MagneticField_lying_Merged.csv
# PATH: Rawdata2/proband13/data/mag_running_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_MagneticField_running_Merged.csv
# PATH: Rawdata2/proband13/data/mag_sitting_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_MagneticField_sitting_Merged.csv
# PATH: Rawdata2/proband13/data/mag_standing_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_MagneticField_standing_Merged.csv
# PATH: Rawdata2/proband13/data/mag_walking_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_MagneticField_walking_Merged.csv
# PATH: Rawdata2/proband13/data/mic_climbingdown_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Microphone_climbingdown_Merged.csv
# PATH: Rawdata2/proband13/data/mic_climbingup_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Microphone_climbingup_Merged.csv
# PATH: Rawdata2/proband13/data/mic_jumping_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Microphone_jumping_Merged.csv
# PATH: Rawdata2/proband13/data/mic_lying_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Microphone_lying_Merged.csv
# PATH: Rawdata2/proband13/data/mic_running_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Microphone_running_Merged.csv
# PATH: Rawdata2/proband13/data/mic_sitting_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Microphone_sitting_Merged.csv
# PATH: Rawdata2/proband13/data/mic_standing_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Microphone_standing_Merged.csv
# PATH: Rawdata2/proband13/data/mic_walking_csv.zip SUBJECT: 13
# MERGE FILE COMPLETE: 13_Microphone_walking_Merged.csv
# PATH: Rawdata2/proband14/data/acc_climbingdown_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_acc_climbingdown_Merged.csv
# PATH: Rawdata2/proband14/data/acc_climbingup_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_acc_climbingup_Merged.csv
# PATH: Rawdata2/proband14/data/acc_jumping_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_acc_jumping_Merged.csv
# PATH: Rawdata2/proband14/data/acc_lying_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_acc_lying_Merged.csv
# PATH: Rawdata2/proband14/data/acc_running_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_acc_running_Merged.csv
# PATH: Rawdata2/proband14/data/acc_sitting_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_acc_sitting_Merged.csv
# PATH: Rawdata2/proband14/data/acc_standing_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_acc_standing_Merged.csv
# PATH: Rawdata2/proband14/data/acc_walking_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_acc_walking_Merged.csv
# PATH: Rawdata2/proband14/data/gps_climbingdown_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_GPS_climbingdown_Merged.csv
# PATH: Rawdata2/proband14/data/gps_climbingup_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_GPS_climbingup_Merged.csv
# PATH: Rawdata2/proband14/data/gps_jumping_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_GPS_jumping_Merged.csv
# PATH: Rawdata2/proband14/data/gps_lying_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_GPS_lying_Merged.csv
# PATH: Rawdata2/proband14/data/gps_running_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_GPS_running_Merged.csv
# PATH: Rawdata2/proband14/data/gps_sitting_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_GPS_sitting_Merged.csv
# PATH: Rawdata2/proband14/data/gps_standing_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_GPS_standing_Merged.csv
# PATH: Rawdata2/proband14/data/gps_walking_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_GPS_walking_Merged.csv
# PATH: Rawdata2/proband14/data/gyr_climbingdown_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Gyroscope_climbingdown_Merged.csv
# PATH: Rawdata2/proband14/data/gyr_climbingup_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Gyroscope_climbingup_Merged.csv
# PATH: Rawdata2/proband14/data/gyr_jumping_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Gyroscope_jumping_Merged.csv
# PATH: Rawdata2/proband14/data/gyr_lying_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Gyroscope_lying_Merged.csv
# PATH: Rawdata2/proband14/data/gyr_running_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Gyroscope_running_Merged.csv
# PATH: Rawdata2/proband14/data/gyr_sitting_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Gyroscope_sitting_Merged.csv
# PATH: Rawdata2/proband14/data/gyr_standing_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Gyroscope_standing_Merged.csv
# PATH: Rawdata2/proband14/data/gyr_walking_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Gyroscope_walking_Merged.csv
# PATH: Rawdata2/proband14/data/lig_climbingdown_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Light_climbingdown_Merged.csv
# PATH: Rawdata2/proband14/data/lig_climbingup_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Light_climbingup_Merged.csv
# PATH: Rawdata2/proband14/data/lig_jumping_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Light_jumping_Merged.csv
# PATH: Rawdata2/proband14/data/lig_lying_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Light_lying_Merged.csv
# PATH: Rawdata2/proband14/data/lig_running_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Light_running_Merged.csv
# PATH: Rawdata2/proband14/data/lig_sitting_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Light_sitting_Merged.csv
# PATH: Rawdata2/proband14/data/lig_standing_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Light_standing_Merged.csv
# PATH: Rawdata2/proband14/data/lig_walking_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Light_walking_Merged.csv
# PATH: Rawdata2/proband14/data/mag_climbingdown_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_MagneticField_climbingdown_Merged.csv
# PATH: Rawdata2/proband14/data/mag_climbingup_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_MagneticField_climbingup_Merged.csv
# PATH: Rawdata2/proband14/data/mag_jumping_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_MagneticField_jumping_Merged.csv
# PATH: Rawdata2/proband14/data/mag_lying_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_MagneticField_lying_Merged.csv
# PATH: Rawdata2/proband14/data/mag_running_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_MagneticField_running_Merged.csv
# PATH: Rawdata2/proband14/data/mag_sitting_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_MagneticField_sitting_Merged.csv
# PATH: Rawdata2/proband14/data/mag_standing_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_MagneticField_standing_Merged.csv
# PATH: Rawdata2/proband14/data/mag_walking_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_MagneticField_walking_Merged.csv
# PATH: Rawdata2/proband14/data/mic_climbingdown_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Microphone_climbingdown_Merged.csv
# PATH: Rawdata2/proband14/data/mic_climbingup_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Microphone_climbingup_Merged.csv
# PATH: Rawdata2/proband14/data/mic_jumping_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Microphone_jumping_Merged.csv
# PATH: Rawdata2/proband14/data/mic_lying_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Microphone_lying_Merged.csv
# PATH: Rawdata2/proband14/data/mic_running_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Microphone_running_Merged.csv
# PATH: Rawdata2/proband14/data/mic_sitting_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Microphone_sitting_Merged.csv
# PATH: Rawdata2/proband14/data/mic_standing_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Microphone_standing_Merged.csv
# PATH: Rawdata2/proband14/data/mic_walking_csv.zip SUBJECT: 14
# MERGE FILE COMPLETE: 14_Microphone_walking_Merged.csv
# PATH: Rawdata2/proband15/data/acc_climbingdown_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_acc_climbingdown_Merged.csv
# PATH: Rawdata2/proband15/data/acc_climbingup_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_acc_climbingup_Merged.csv
# PATH: Rawdata2/proband15/data/acc_jumping_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_acc_jumping_Merged.csv
# PATH: Rawdata2/proband15/data/acc_lying_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_acc_lying_Merged.csv
# PATH: Rawdata2/proband15/data/acc_running_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_acc_running_Merged.csv
# PATH: Rawdata2/proband15/data/acc_sitting_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_acc_sitting_Merged.csv
# PATH: Rawdata2/proband15/data/acc_standing_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_acc_standing_Merged.csv
# PATH: Rawdata2/proband15/data/acc_walking_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_acc_walking_Merged.csv
# PATH: Rawdata2/proband15/data/gps_climbingdown_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_GPS_climbingdown_Merged.csv
# PATH: Rawdata2/proband15/data/gps_climbingup_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_GPS_climbingup_Merged.csv
# PATH: Rawdata2/proband15/data/gps_jumping_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_GPS_jumping_Merged.csv
# PATH: Rawdata2/proband15/data/gps_lying_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_GPS_lying_Merged.csv
# PATH: Rawdata2/proband15/data/gps_running_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_GPS_running_Merged.csv
# PATH: Rawdata2/proband15/data/gps_sitting_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_GPS_sitting_Merged.csv
# PATH: Rawdata2/proband15/data/gps_standing_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_GPS_standing_Merged.csv
# PATH: Rawdata2/proband15/data/gps_walking_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_GPS_walking_Merged.csv
# PATH: Rawdata2/proband15/data/gyr_climbingdown_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Gyroscope_climbingdown_Merged.csv
# PATH: Rawdata2/proband15/data/gyr_climbingup_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Gyroscope_climbingup_Merged.csv
# PATH: Rawdata2/proband15/data/gyr_jumping_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Gyroscope_jumping_Merged.csv
# PATH: Rawdata2/proband15/data/gyr_lying_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Gyroscope_lying_Merged.csv
# PATH: Rawdata2/proband15/data/gyr_running_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Gyroscope_running_Merged.csv
# PATH: Rawdata2/proband15/data/gyr_sitting_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Gyroscope_sitting_Merged.csv
# PATH: Rawdata2/proband15/data/gyr_standing_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Gyroscope_standing_Merged.csv
# PATH: Rawdata2/proband15/data/gyr_walking_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Gyroscope_walking_Merged.csv
# PATH: Rawdata2/proband15/data/lig_climbingdown_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Light_climbingdown_Merged.csv
# PATH: Rawdata2/proband15/data/lig_climbingup_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Light_climbingup_Merged.csv
# PATH: Rawdata2/proband15/data/lig_jumping_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Light_jumping_Merged.csv
# PATH: Rawdata2/proband15/data/lig_lying_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Light_lying_Merged.csv
# PATH: Rawdata2/proband15/data/lig_running_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Light_running_Merged.csv
# PATH: Rawdata2/proband15/data/lig_sitting_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Light_sitting_Merged.csv
# PATH: Rawdata2/proband15/data/lig_standing_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Light_standing_Merged.csv
# PATH: Rawdata2/proband15/data/lig_walking_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Light_walking_Merged.csv
# PATH: Rawdata2/proband15/data/mag_climbingdown_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_MagneticField_climbingdown_Merged.csv
# PATH: Rawdata2/proband15/data/mag_climbingup_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_MagneticField_climbingup_Merged.csv
# PATH: Rawdata2/proband15/data/mag_jumping_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_MagneticField_jumping_Merged.csv
# PATH: Rawdata2/proband15/data/mag_lying_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_MagneticField_lying_Merged.csv
# PATH: Rawdata2/proband15/data/mag_running_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_MagneticField_running_Merged.csv
# PATH: Rawdata2/proband15/data/mag_sitting_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_MagneticField_sitting_Merged.csv
# PATH: Rawdata2/proband15/data/mag_standing_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_MagneticField_standing_Merged.csv
# PATH: Rawdata2/proband15/data/mag_walking_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_MagneticField_walking_Merged.csv
# PATH: Rawdata2/proband15/data/mic_climbingdown_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Microphone_climbingdown_Merged.csv
# PATH: Rawdata2/proband15/data/mic_climbingup_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Microphone_climbingup_Merged.csv
# PATH: Rawdata2/proband15/data/mic_jumping_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Microphone_jumping_Merged.csv
# PATH: Rawdata2/proband15/data/mic_lying_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Microphone_lying_Merged.csv
# PATH: Rawdata2/proband15/data/mic_running_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Microphone_running_Merged.csv
# PATH: Rawdata2/proband15/data/mic_sitting_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Microphone_sitting_Merged.csv
# PATH: Rawdata2/proband15/data/mic_standing_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Microphone_standing_Merged.csv
# PATH: Rawdata2/proband15/data/mic_walking_csv.zip SUBJECT: 15
# MERGE FILE COMPLETE: 15_Microphone_walking_Merged.csv
# PATH: Rawdata2/proband2/data/acc_climbingdown_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_acc_climbingdown_Merged.csv
# PATH: Rawdata2/proband2/data/acc_climbingup_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_acc_climbingup_Merged.csv
# PATH: Rawdata2/proband2/data/acc_jumping_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_acc_jumping_Merged.csv
# PATH: Rawdata2/proband2/data/acc_lying_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_acc_lying_Merged.csv
# PATH: Rawdata2/proband2/data/acc_running_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_acc_running_Merged.csv
# PATH: Rawdata2/proband2/data/acc_sitting_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_acc_sitting_Merged.csv
# PATH: Rawdata2/proband2/data/acc_standing_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_acc_standing_Merged.csv
# PATH: Rawdata2/proband2/data/acc_walking_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_acc_walking_Merged.csv
# PATH: Rawdata2/proband2/data/gps_climbingdown_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_GPS_climbingdown_Merged.csv
# PATH: Rawdata2/proband2/data/gps_climbingup_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_GPS_climbingup_Merged.csv
# PATH: Rawdata2/proband2/data/gps_jumping_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_GPS_jumping_Merged.csv
# PATH: Rawdata2/proband2/data/gps_lying_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_GPS_lying_Merged.csv
# PATH: Rawdata2/proband2/data/gps_running_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_GPS_running_Merged.csv
# PATH: Rawdata2/proband2/data/gps_sitting_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_GPS_sitting_Merged.csv
# PATH: Rawdata2/proband2/data/gps_standing_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_GPS_standing_Merged.csv
# PATH: Rawdata2/proband2/data/gps_walking_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_GPS_walking_Merged.csv
# PATH: Rawdata2/proband2/data/gyr_climbingdown_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Gyroscope_climbingdown_Merged.csv
# PATH: Rawdata2/proband2/data/gyr_climbingup_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Gyroscope_climbingup_Merged.csv
# PATH: Rawdata2/proband2/data/gyr_jumping_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Gyroscope_jumping_Merged.csv
# PATH: Rawdata2/proband2/data/gyr_lying_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Gyroscope_lying_Merged.csv
# PATH: Rawdata2/proband2/data/gyr_running_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Gyroscope_running_Merged.csv
# PATH: Rawdata2/proband2/data/gyr_sitting_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Gyroscope_sitting_Merged.csv
# PATH: Rawdata2/proband2/data/gyr_standing_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Gyroscope_standing_Merged.csv
# PATH: Rawdata2/proband2/data/gyr_walking_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Gyroscope_walking_Merged.csv
# PATH: Rawdata2/proband2/data/lig_climbingdown_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Light_climbingdown_Merged.csv
# PATH: Rawdata2/proband2/data/lig_climbingup_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Light_climbingup_Merged.csv
# PATH: Rawdata2/proband2/data/lig_jumping_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Light_jumping_Merged.csv
# PATH: Rawdata2/proband2/data/lig_lying_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Light_lying_Merged.csv
# PATH: Rawdata2/proband2/data/lig_running_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Light_running_Merged.csv
# PATH: Rawdata2/proband2/data/lig_sitting_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Light_sitting_Merged.csv
# PATH: Rawdata2/proband2/data/lig_standing_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Light_standing_Merged.csv
# PATH: Rawdata2/proband2/data/lig_walking_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Light_walking_Merged.csv
# PATH: Rawdata2/proband2/data/mag_climbingdown_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_MagneticField_climbingdown_Merged.csv
# PATH: Rawdata2/proband2/data/mag_climbingup_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_MagneticField_climbingup_Merged.csv
# PATH: Rawdata2/proband2/data/mag_jumping_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_MagneticField_jumping_Merged.csv
# PATH: Rawdata2/proband2/data/mag_lying_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_MagneticField_lying_Merged.csv
# PATH: Rawdata2/proband2/data/mag_running_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_MagneticField_running_Merged.csv
# PATH: Rawdata2/proband2/data/mag_sitting_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_MagneticField_sitting_Merged.csv
# PATH: Rawdata2/proband2/data/mag_standing_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_MagneticField_standing_Merged.csv
# PATH: Rawdata2/proband2/data/mag_walking_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_MagneticField_walking_Merged.csv
# PATH: Rawdata2/proband2/data/mic_climbingdown_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Microphone_climbingdown_Merged.csv
# PATH: Rawdata2/proband2/data/mic_climbingup_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Microphone_climbingup_Merged.csv
# PATH: Rawdata2/proband2/data/mic_jumping_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Microphone_jumping_Merged.csv
# PATH: Rawdata2/proband2/data/mic_lying_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Microphone_lying_Merged.csv
# PATH: Rawdata2/proband2/data/mic_running_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Microphone_running_Merged.csv
# PATH: Rawdata2/proband2/data/mic_sitting_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Microphone_sitting_Merged.csv
# PATH: Rawdata2/proband2/data/mic_standing_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Microphone_standing_Merged.csv
# PATH: Rawdata2/proband2/data/mic_walking_csv.zip SUBJECT: 2
# MERGE FILE COMPLETE: 2_Microphone_walking_Merged.csv
# PATH: Rawdata2/proband3/data/acc_climbingdown_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_acc_climbingdown_Merged.csv
# PATH: Rawdata2/proband3/data/acc_climbingup_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_acc_climbingup_Merged.csv
# PATH: Rawdata2/proband3/data/acc_jumping_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_acc_jumping_Merged.csv
# PATH: Rawdata2/proband3/data/acc_lying_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_acc_lying_Merged.csv
# PATH: Rawdata2/proband3/data/acc_running_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_acc_running_Merged.csv
# PATH: Rawdata2/proband3/data/acc_sitting_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_acc_sitting_Merged.csv
# PATH: Rawdata2/proband3/data/acc_standing_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_acc_standing_Merged.csv
# PATH: Rawdata2/proband3/data/acc_walking_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_acc_walking_Merged.csv
# PATH: Rawdata2/proband3/data/gps_climbingdown_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_GPS_climbingdown_Merged.csv
# PATH: Rawdata2/proband3/data/gps_climbingup_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_GPS_climbingup_Merged.csv
# PATH: Rawdata2/proband3/data/gps_jumping_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_GPS_jumping_Merged.csv
# PATH: Rawdata2/proband3/data/gps_lying_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_GPS_lying_Merged.csv
# PATH: Rawdata2/proband3/data/gps_running_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_GPS_running_Merged.csv
# PATH: Rawdata2/proband3/data/gps_sitting_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_GPS_sitting_Merged.csv
# PATH: Rawdata2/proband3/data/gps_standing_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_GPS_standing_Merged.csv
# PATH: Rawdata2/proband3/data/gps_walking_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_GPS_walking_Merged.csv
# PATH: Rawdata2/proband3/data/gyr_climbingdown_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_Gyroscope_climbingdown_Merged.csv
# PATH: Rawdata2/proband3/data/gyr_climbingup_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_Gyroscope_climbingup_Merged.csv
# PATH: Rawdata2/proband3/data/gyr_jumping_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_Gyroscope_jumping_Merged.csv
# PATH: Rawdata2/proband3/data/gyr_lying_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_Gyroscope_lying_Merged.csv
# PATH: Rawdata2/proband3/data/gyr_running_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_Gyroscope_running_Merged.csv
# PATH: Rawdata2/proband3/data/gyr_sitting_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_Gyroscope_sitting_Merged.csv
# PATH: Rawdata2/proband3/data/gyr_standing_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_Gyroscope_standing_Merged.csv
# PATH: Rawdata2/proband3/data/gyr_walking_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_Gyroscope_walking_Merged.csv
# PATH: Rawdata2/proband3/data/lig_climbingdown_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_Light_climbingdown_Merged.csv
# PATH: Rawdata2/proband3/data/lig_climbingup_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_Light_climbingup_Merged.csv
# PATH: Rawdata2/proband3/data/lig_jumping_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_Light_jumping_Merged.csv
# PATH: Rawdata2/proband3/data/lig_lying_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_Light_lying_Merged.csv
# PATH: Rawdata2/proband3/data/lig_running_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_Light_running_Merged.csv
# PATH: Rawdata2/proband3/data/lig_sitting_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_Light_sitting_Merged.csv
# PATH: Rawdata2/proband3/data/lig_standing_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_Light_standing_Merged.csv
# PATH: Rawdata2/proband3/data/lig_walking_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_Light_walking_Merged.csv
# PATH: Rawdata2/proband3/data/mag_climbingdown_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_MagneticField_climbingdown_Merged.csv
# PATH: Rawdata2/proband3/data/mag_climbingup_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_MagneticField_climbingup_Merged.csv
# PATH: Rawdata2/proband3/data/mag_jumping_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_MagneticField_jumping_Merged.csv
# PATH: Rawdata2/proband3/data/mag_lying_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_MagneticField_lying_Merged.csv
# PATH: Rawdata2/proband3/data/mag_running_csv.zip SUBJECT: 3
# MERGE FILE COMPLETE: 3_MagneticField_running_Merged.csv
# ...
# MERGE FILE COMPLETE: 6_Microphone_walking_Merged.csv
# PATH: Rawdata2/proband7/data/acc_climbingdown_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_acc_climbingdown_Merged.csv
# PATH: Rawdata2/proband7/data/acc_climbingup_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_acc_climbingup_Merged.csv
# PATH: Rawdata2/proband7/data/acc_jumping_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_acc_jumping_Merged.csv
# PATH: Rawdata2/proband7/data/acc_lying_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_acc_lying_Merged.csv
# PATH: Rawdata2/proband7/data/acc_running_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_acc_running_Merged.csv
# PATH: Rawdata2/proband7/data/acc_sitting_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_acc_sitting_Merged.csv
# PATH: Rawdata2/proband7/data/acc_standing_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_acc_standing_Merged.csv
# PATH: Rawdata2/proband7/data/acc_walking_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_acc_walking_Merged.csv
# PATH: Rawdata2/proband7/data/gps_climbingdown_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_GPS_climbingdown_Merged.csv
# PATH: Rawdata2/proband7/data/gps_climbingup_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_GPS_climbingup_Merged.csv
# PATH: Rawdata2/proband7/data/gps_jumping_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_GPS_jumping_Merged.csv
# PATH: Rawdata2/proband7/data/gps_lying_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_GPS_lying_Merged.csv
# PATH: Rawdata2/proband7/data/gps_running_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_GPS_running_Merged.csv
# PATH: Rawdata2/proband7/data/gps_sitting_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_GPS_sitting_Merged.csv
# PATH: Rawdata2/proband7/data/gps_standing_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_GPS_standing_Merged.csv
# PATH: Rawdata2/proband7/data/gps_walking_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_GPS_walking_Merged.csv
# PATH: Rawdata2/proband7/data/gyr_climbingdown_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Gyroscope_climbingdown_Merged.csv
# PATH: Rawdata2/proband7/data/gyr_climbingup_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Gyroscope_climbingup_Merged.csv
# PATH: Rawdata2/proband7/data/gyr_jumping_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Gyroscope_jumping_Merged.csv
# PATH: Rawdata2/proband7/data/gyr_lying_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Gyroscope_lying_Merged.csv
# PATH: Rawdata2/proband7/data/gyr_running_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Gyroscope_running_Merged.csv
# PATH: Rawdata2/proband7/data/gyr_sitting_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Gyroscope_sitting_Merged.csv
# PATH: Rawdata2/proband7/data/gyr_standing_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Gyroscope_standing_Merged.csv
# PATH: Rawdata2/proband7/data/gyr_walking_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Gyroscope_walking_Merged.csv
# PATH: Rawdata2/proband7/data/lig_climbingdown_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Light_climbingdown_Merged.csv
# PATH: Rawdata2/proband7/data/lig_climbingup_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Light_climbingup_Merged.csv
# PATH: Rawdata2/proband7/data/lig_jumping_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Light_jumping_Merged.csv
# PATH: Rawdata2/proband7/data/lig_lying_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Light_lying_Merged.csv
# PATH: Rawdata2/proband7/data/lig_running_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Light_running_Merged.csv
# PATH: Rawdata2/proband7/data/lig_sitting_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Light_sitting_Merged.csv
# PATH: Rawdata2/proband7/data/lig_standing_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Light_standing_Merged.csv
# PATH: Rawdata2/proband7/data/lig_walking_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Light_walking_Merged.csv
# PATH: Rawdata2/proband7/data/mag_climbingdown_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_MagneticField_climbingdown_Merged.csv
# PATH: Rawdata2/proband7/data/mag_climbingup_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_MagneticField_climbingup_Merged.csv
# PATH: Rawdata2/proband7/data/mag_jumping_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_MagneticField_jumping_Merged.csv
# PATH: Rawdata2/proband7/data/mag_lying_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_MagneticField_lying_Merged.csv
# PATH: Rawdata2/proband7/data/mag_running_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_MagneticField_running_Merged.csv
# PATH: Rawdata2/proband7/data/mag_sitting_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_MagneticField_sitting_Merged.csv
# PATH: Rawdata2/proband7/data/mag_standing_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_MagneticField_standing_Merged.csv
# PATH: Rawdata2/proband7/data/mag_walking_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_MagneticField_walking_Merged.csv
# PATH: Rawdata2/proband7/data/mic_climbingdown_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Microphone_climbingdown_Merged.csv
# PATH: Rawdata2/proband7/data/mic_climbingup_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Microphone_climbingup_Merged.csv
# PATH: Rawdata2/proband7/data/mic_jumping_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Microphone_jumping_Merged.csv
# PATH: Rawdata2/proband7/data/mic_lying_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Microphone_lying_Merged.csv
# PATH: Rawdata2/proband7/data/mic_running_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Microphone_running_Merged.csv
# PATH: Rawdata2/proband7/data/mic_sitting_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Microphone_sitting_Merged.csv
# PATH: Rawdata2/proband7/data/mic_standing_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Microphone_standing_Merged.csv
# PATH: Rawdata2/proband7/data/mic_walking_csv.zip SUBJECT: 7
# MERGE FILE COMPLETE: 7_Microphone_walking_Merged.csv
# PATH: Rawdata2/proband8/data/acc_climbingdown_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_acc_climbingdown_Merged.csv
# PATH: Rawdata2/proband8/data/acc_climbingup_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_acc_climbingup_Merged.csv
# PATH: Rawdata2/proband8/data/acc_jumping_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_acc_jumping_Merged.csv
# PATH: Rawdata2/proband8/data/acc_lying_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_acc_lying_Merged.csv
# PATH: Rawdata2/proband8/data/acc_running_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_acc_running_Merged.csv
# PATH: Rawdata2/proband8/data/acc_sitting_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_acc_sitting_Merged.csv
# PATH: Rawdata2/proband8/data/acc_standing_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_acc_standing_Merged.csv
# PATH: Rawdata2/proband8/data/acc_walking_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_acc_walking_Merged.csv
# PATH: Rawdata2/proband8/data/gps_climbingdown_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_GPS_climbingdown_Merged.csv
# PATH: Rawdata2/proband8/data/gps_climbingup_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_GPS_climbingup_Merged.csv
# PATH: Rawdata2/proband8/data/gps_lying_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_GPS_lying_Merged.csv
# PATH: Rawdata2/proband8/data/gps_sitting_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_GPS_sitting_Merged.csv
# PATH: Rawdata2/proband8/data/gps_standing_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_GPS_standing_Merged.csv
# PATH: Rawdata2/proband8/data/gps_walking_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_GPS_walking_Merged.csv
# PATH: Rawdata2/proband8/data/gyr_climbingdown_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Gyroscope_climbingdown_Merged.csv
# PATH: Rawdata2/proband8/data/gyr_climbingup_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Gyroscope_climbingup_Merged.csv
# PATH: Rawdata2/proband8/data/gyr_jumping_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Gyroscope_jumping_Merged.csv
# PATH: Rawdata2/proband8/data/gyr_lying_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Gyroscope_lying_Merged.csv
# PATH: Rawdata2/proband8/data/gyr_running_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Gyroscope_running_Merged.csv
# PATH: Rawdata2/proband8/data/gyr_sitting_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Gyroscope_sitting_Merged.csv
# PATH: Rawdata2/proband8/data/gyr_standing_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Gyroscope_standing_Merged.csv
# PATH: Rawdata2/proband8/data/gyr_walking_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Gyroscope_walking_Merged.csv
# PATH: Rawdata2/proband8/data/lig_climbingdown_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Light_climbingdown_Merged.csv
# PATH: Rawdata2/proband8/data/lig_climbingup_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Light_climbingup_Merged.csv
# PATH: Rawdata2/proband8/data/lig_jumping_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Light_jumping_Merged.csv
# PATH: Rawdata2/proband8/data/lig_lying_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Light_lying_Merged.csv
# PATH: Rawdata2/proband8/data/lig_running_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Light_running_Merged.csv
# PATH: Rawdata2/proband8/data/lig_sitting_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Light_sitting_Merged.csv
# PATH: Rawdata2/proband8/data/lig_standing_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Light_standing_Merged.csv
# PATH: Rawdata2/proband8/data/lig_walking_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Light_walking_Merged.csv
# PATH: Rawdata2/proband8/data/mag_climbingdown_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_MagneticField_climbingdown_Merged.csv
# PATH: Rawdata2/proband8/data/mag_climbingup_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_MagneticField_climbingup_Merged.csv
# PATH: Rawdata2/proband8/data/mag_jumping_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_MagneticField_jumping_Merged.csv
# PATH: Rawdata2/proband8/data/mag_lying_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_MagneticField_lying_Merged.csv
# PATH: Rawdata2/proband8/data/mag_running_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_MagneticField_running_Merged.csv
# PATH: Rawdata2/proband8/data/mag_sitting_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_MagneticField_sitting_Merged.csv
# PATH: Rawdata2/proband8/data/mag_standing_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_MagneticField_standing_Merged.csv
# PATH: Rawdata2/proband8/data/mag_walking_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_MagneticField_walking_Merged.csv
# PATH: Rawdata2/proband8/data/mic_climbingdown_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Microphone_climbingdown_Merged.csv
# PATH: Rawdata2/proband8/data/mic_climbingup_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Microphone_climbingup_Merged.csv
# PATH: Rawdata2/proband8/data/mic_jumping_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Microphone_jumping_Merged.csv
# PATH: Rawdata2/proband8/data/mic_lying_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Microphone_lying_Merged.csv
# PATH: Rawdata2/proband8/data/mic_running_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Microphone_running_Merged.csv
# PATH: Rawdata2/proband8/data/mic_sitting_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Microphone_sitting_Merged.csv
# PATH: Rawdata2/proband8/data/mic_standing_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Microphone_standing_Merged.csv
# PATH: Rawdata2/proband8/data/mic_walking_csv.zip SUBJECT: 8
# MERGE FILE COMPLETE: 8_Microphone_walking_Merged.csv
# PATH: Rawdata2/proband9/data/acc_climbingdown_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_acc_climbingdown_Merged.csv
# PATH: Rawdata2/proband9/data/acc_climbingup_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_acc_climbingup_Merged.csv
# PATH: Rawdata2/proband9/data/acc_jumping_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_acc_jumping_Merged.csv
# PATH: Rawdata2/proband9/data/acc_lying_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_acc_lying_Merged.csv
# PATH: Rawdata2/proband9/data/acc_running_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_acc_running_Merged.csv
# PATH: Rawdata2/proband9/data/acc_sitting_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_acc_sitting_Merged.csv
# PATH: Rawdata2/proband9/data/acc_standing_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_acc_standing_Merged.csv
# PATH: Rawdata2/proband9/data/acc_walking_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_acc_walking_Merged.csv
# PATH: Rawdata2/proband9/data/gps_climbingdown_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_GPS_climbingdown_Merged.csv
# PATH: Rawdata2/proband9/data/gps_climbingup_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_GPS_climbingup_Merged.csv
# PATH: Rawdata2/proband9/data/gps_jumping_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_GPS_jumping_Merged.csv
# PATH: Rawdata2/proband9/data/gps_lying_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_GPS_lying_Merged.csv
# PATH: Rawdata2/proband9/data/gps_running_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_GPS_running_Merged.csv
# PATH: Rawdata2/proband9/data/gps_sitting_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_GPS_sitting_Merged.csv
# PATH: Rawdata2/proband9/data/gps_standing_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_GPS_standing_Merged.csv
# PATH: Rawdata2/proband9/data/gps_walking_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_GPS_walking_Merged.csv
# PATH: Rawdata2/proband9/data/gyr_climbingdown_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Gyroscope_climbingdown_Merged.csv
# PATH: Rawdata2/proband9/data/gyr_climbingup_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Gyroscope_climbingup_Merged.csv
# PATH: Rawdata2/proband9/data/gyr_jumping_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Gyroscope_jumping_Merged.csv
# PATH: Rawdata2/proband9/data/gyr_lying_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Gyroscope_lying_Merged.csv
# PATH: Rawdata2/proband9/data/gyr_running_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Gyroscope_running_Merged.csv
# PATH: Rawdata2/proband9/data/gyr_sitting_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Gyroscope_sitting_Merged.csv
# PATH: Rawdata2/proband9/data/gyr_standing_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Gyroscope_standing_Merged.csv
# PATH: Rawdata2/proband9/data/gyr_walking_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Gyroscope_walking_Merged.csv
# PATH: Rawdata2/proband9/data/lig_climbingdown_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Light_climbingdown_Merged.csv
# PATH: Rawdata2/proband9/data/lig_climbingup_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Light_climbingup_Merged.csv
# PATH: Rawdata2/proband9/data/lig_jumping_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Light_jumping_Merged.csv
# PATH: Rawdata2/proband9/data/lig_lying_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Light_lying_Merged.csv
# PATH: Rawdata2/proband9/data/lig_running_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Light_running_Merged.csv
# PATH: Rawdata2/proband9/data/lig_sitting_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Light_sitting_Merged.csv
# PATH: Rawdata2/proband9/data/lig_standing_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Light_standing_Merged.csv
# PATH: Rawdata2/proband9/data/lig_walking_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Light_walking_Merged.csv
# PATH: Rawdata2/proband9/data/mag_climbingdown_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_MagneticField_climbingdown_Merged.csv
# PATH: Rawdata2/proband9/data/mag_climbingup_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_MagneticField_climbingup_Merged.csv
# PATH: Rawdata2/proband9/data/mag_jumping_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_MagneticField_jumping_Merged.csv
# PATH: Rawdata2/proband9/data/mag_lying_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_MagneticField_lying_Merged.csv
# PATH: Rawdata2/proband9/data/mag_running_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_MagneticField_running_Merged.csv
# PATH: Rawdata2/proband9/data/mag_sitting_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_MagneticField_sitting_Merged.csv
# PATH: Rawdata2/proband9/data/mag_standing_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_MagneticField_standing_Merged.csv
# PATH: Rawdata2/proband9/data/mag_walking_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_MagneticField_walking_Merged.csv
# PATH: Rawdata2/proband9/data/mic_climbingdown_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Microphone_climbingdown_Merged.csv
# PATH: Rawdata2/proband9/data/mic_climbingup_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Microphone_climbingup_Merged.csv
# PATH: Rawdata2/proband9/data/mic_jumping_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Microphone_jumping_Merged.csv
# PATH: Rawdata2/proband9/data/mic_lying_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Microphone_lying_Merged.csv
# PATH: Rawdata2/proband9/data/mic_running_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Microphone_running_Merged.csv
# PATH: Rawdata2/proband9/data/mic_sitting_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Microphone_sitting_Merged.csv
# PATH: Rawdata2/proband9/data/mic_standing_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Microphone_standing_Merged.csv
# PATH: Rawdata2/proband9/data/mic_walking_csv.zip SUBJECT: 9
# MERGE FILE COMPLETE: 9_Microphone_walking_Merged.csv

# %%
#adjust to what sensor you want a file to merge
#make dataset containing all csv's of accuracy
import glob
dir = os.getcwd()
dirs = os.listdir(dir)
sensor = 'acc' #acc, gyr, mag

for item in dirs:
    newdirs = glob.glob('*' + sensor + '*.csv')

# %%
count = 0
for csv in newdirs:    
    if count == 0:
        df = pd.read_csv(csv)
    else: 
        df2 = pd.read_csv(csv)
        merged_df = df.append(df2)
        df = merged_df
        print(csv)
        print(merged_df.shape)
    count += 1
# Out:
# 10_GPS_climbingup_Merged.csv
# (57, 23)
# 10_GPS_jumping_Merged.csv
# (63, 23)
# 10_GPS_lying_Merged.csv
# (122, 23)
# 10_GPS_running_Merged.csv
# (166, 23)
# 10_GPS_sitting_Merged.csv
# (199, 23)
# 10_GPS_standing_Merged.csv
# (225, 23)
# 10_GPS_walking_Merged.csv
# (270, 23)
# 11_GPS_climbingdown_Merged.csv
# (308, 23)
# 11_GPS_climbingup_Merged.csv
# (344, 23)
# 11_GPS_jumping_Merged.csv
# (352, 23)
# 11_GPS_lying_Merged.csv
# (384, 23)
# 11_GPS_running_Merged.csv
# (427, 23)
# 11_GPS_sitting_Merged.csv
# (458, 23)
# 11_GPS_standing_Merged.csv
# (486, 23)
# 11_GPS_walking_Merged.csv
# (542, 23)
# 12_GPS_climbingdown_Merged.csv
# (579, 23)
# 12_GPS_climbingup_Merged.csv
# (611, 23)
# 12_GPS_jumping_Merged.csv
# (620, 23)
# 12_GPS_lying_Merged.csv
# (651, 23)
# 12_GPS_running_Merged.csv
# (674, 23)
# 12_GPS_sitting_Merged.csv
# (713, 23)
# 12_GPS_standing_Merged.csv
# (749, 23)
# 12_GPS_walking_Merged.csv
# (767, 23)
# 13_GPS_climbingdown_Merged.csv
# (791, 23)
# 13_GPS_climbingup_Merged.csv
# (828, 23)
# 13_GPS_jumping_Merged.csv
# (833, 23)
# 13_GPS_lying_Merged.csv
# (865, 23)
# 13_GPS_running_Merged.csv
# (906, 23)
# 13_GPS_sitting_Merged.csv
# (960, 23)
# 13_GPS_standing_Merged.csv
# (1010, 23)
# 13_GPS_walking_Merged.csv
# (1053, 23)
# 14_GPS_climbingdown_Merged.csv
# (1059, 23)
# 14_GPS_climbingup_Merged.csv
# (1063, 23)
# 14_GPS_jumping_Merged.csv
# (1071, 23)
# 14_GPS_lying_Merged.csv
# (1095, 23)
# 14_GPS_running_Merged.csv
# (1118, 23)
# 14_GPS_sitting_Merged.csv
# (1119, 23)
# 14_GPS_standing_Merged.csv
# (1159, 23)
# 14_GPS_walking_Merged.csv
# (1191, 23)
# 15_GPS_climbingdown_Merged.csv
# (1223, 23)
# 15_GPS_climbingup_Merged.csv
# (1247, 26)
# 15_GPS_jumping_Merged.csv
# (1254, 26)
# 15_GPS_lying_Merged.csv
# (1287, 26)
# 15_GPS_running_Merged.csv
# (1322, 26)
# 15_GPS_sitting_Merged.csv
# (1342, 26)
# 15_GPS_standing_Merged.csv
# (1385, 26)
# 15_GPS_walking_Merged.csv
# (1418, 26)
# 1_GPS_climbingdown_Merged.csv
# (1446, 26)
# 1_GPS_climbingup_Merged.csv
# (1467, 26)
# 1_GPS_jumping_Merged.csv
# (1471, 26)
# 1_GPS_lying_Merged.csv
# (1501, 26)
# 1_GPS_running_Merged.csv
# (1547, 26)
# 1_GPS_sitting_Merged.csv
# (1602, 26)
# 1_GPS_standing_Merged.csv
# (1629, 26)
# 1_GPS_walking_Merged.csv
# (1649, 26)
# 2_GPS_climbingdown_Merged.csv
# (1685, 26)
# 2_GPS_climbingup_Merged.csv
# (1721, 26)
# 2_GPS_jumping_Merged.csv
# (1725, 26)
# 2_GPS_lying_Merged.csv
# (1756, 26)
# 2_GPS_running_Merged.csv
# (1805, 26)
# 2_GPS_sitting_Merged.csv
# (1833, 26)
# 2_GPS_standing_Merged.csv
# (1890, 26)
# 2_GPS_walking_Merged.csv
# (1947, 26)
# 3_GPS_climbingdown_Merged.csv
# (1984, 26)
# 3_GPS_climbingup_Merged.csv
# (2021, 26)
# 3_GPS_jumping_Merged.csv
# (2026, 26)
# 3_GPS_lying_Merged.csv
# (2057, 26)
# 3_GPS_running_Merged.csv
# (2106, 26)
# 3_GPS_sitting_Merged.csv
# (2136, 26)
# 3_GPS_standing_Merged.csv
# (2190, 26)
# 3_GPS_walking_Merged.csv
# (2242, 26)
# 4_GPS_climbingdown_Merged.csv
# (2249, 26)
# 4_GPS_climbingup_Merged.csv
# (2252, 26)
# 4_GPS_jumping_Merged.csv
# (2255, 26)
# 4_GPS_lying_Merged.csv
# (2258, 26)
# 4_GPS_running_Merged.csv
# (2354, 26)
# 4_GPS_sitting_Merged.csv
# (2385, 26)
# 4_GPS_standing_Merged.csv
# (2442, 26)
# 4_GPS_walking_Merged.csv
# (2494, 26)
# 5_GPS_climbingdown_Merged.csv
# (2496, 26)
# 5_GPS_climbingup_Merged.csv
# (2528, 26)
# 5_GPS_jumping_Merged.csv
# (2536, 26)
# 5_GPS_lying_Merged.csv
# (2575, 26)
# 5_GPS_running_Merged.csv
# (2667, 26)
# 5_GPS_sitting_Merged.csv
# (2699, 26)
# 5_GPS_standing_Merged.csv
# (2746, 26)
# 5_GPS_walking_Merged.csv
# (2804, 26)
# 6_GPS_climbingdown_Merged.csv
# (2840, 26)
# 6_GPS_climbingup_Merged.csv
# (2880, 26)
# 6_GPS_jumping_Merged.csv
# (2888, 26)
# 6_GPS_lying_Merged.csv
# (2921, 26)
# 6_GPS_running_Merged.csv
# (2975, 26)
# 6_GPS_sitting_Merged.csv
# (3006, 26)
# 6_GPS_standing_Merged.csv
# (3061, 26)
# 6_GPS_walking_Merged.csv
# (3079, 26)
# 7_GPS_climbingdown_Merged.csv
# (3086, 26)
# 7_GPS_climbingup_Merged.csv
# (3093, 26)
# 7_GPS_jumping_Merged.csv
# (3101, 26)
# 7_GPS_lying_Merged.csv
# (3162, 26)
# 7_GPS_running_Merged.csv
# (3231, 26)
# 7_GPS_sitting_Merged.csv
# (3281, 26)
# 7_GPS_standing_Merged.csv
# (3341, 26)
# 7_GPS_walking_Merged.csv
# (3385, 26)
# 8_GPS_climbingdown_Merged.csv
# (3392, 26)
# 8_GPS_climbingup_Merged.csv
# (3440, 26)
# 8_GPS_lying_Merged.csv
# (3471, 26)
# 8_GPS_sitting_Merged.csv
# (3503, 26)
# 8_GPS_standing_Merged.csv
# (3535, 26)
# 8_GPS_walking_Merged.csv
# (3585, 26)
# 9_GPS_climbingdown_Merged.csv
# (3613, 26)
# 9_GPS_climbingup_Merged.csv
# (3642, 26)
# 9_GPS_jumping_Merged.csv
# (3649, 26)
# 9_GPS_lying_Merged.csv
# (3680, 26)
# 9_GPS_running_Merged.csv
# (3730, 26)
# 9_GPS_sitting_Merged.csv
# (3765, 26)
# 9_GPS_standing_Merged.csv
# (3798, 26)
# 9_GPS_walking_Merged.csv
# (3841, 26)

# %%
#name temporary file
merged_df.to_csv("tempfile_acc.csv", index=True)

#the same is done for gyroscope - tempfile_gyr.csv
#the same is done for magnetometer - tempfile_mag.csv
